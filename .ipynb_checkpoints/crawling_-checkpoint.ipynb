# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import pandas as pd
import numpy as np
from datetime import datetime
import time
import re
# 행 많이보기
pd.set_option('display.max_row', 500)
pd.set_option('display.max_columns', 100)

# 한글 폰트 설정

fm.get_fontconfig_fonts()
font_location = 'C:/Windows/Fonts/NanumGothic.ttf' # For Windows
font_name = fm.FontProperties(fname=font_location).get_name()
plt.rc('font', family=font_name)
plt.rc('font', size=12)
plt.figure(figsize=(20,10))

# %%
# 필요한 모듈 불러오기
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # ns 다시

# %%
url = 'https://www.nsmall.com/'
#headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}
req = requests.get(url)
html = req.text
soup = BeautifulSoup(html, 'html.parser', from_encoding='utf-8')
soup1 = list(soup.children)[3]
body1 = list(soup1.children)[3]
# Out:
# C:\python\envs\cpu_env\lib\site-packages\bs4\__init__.py:146: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")

# %%
C1_len = len(list(body1.select('div.category_list_wrap > ul')))

result = []
for i in range(C1_len) : # C1_len
    tmp = list(body1.select('div.category_list_wrap > h3'))[i]
    name1 = tmp.text
    C2_len = len(list(body1.select('div.category_list_wrap > ul > li.cate_item')))


    for j in range(C2_len) : #C2_len
        ttmp = list(body1.select('div.category_list_wrap > ul > li.cate_item'))[j]
        name2 = ttmp.select('a > span')[0].text
        C3_len = len(list(ttmp.select('div.low_depth_wrap > ul > li')))

        for k in range(C3_len) : #C3_len
            tttmp = list(ttmp.select('div.low_depth_wrap > ul > li'))[k]
            name3 = tttmp.select('a > span')[0].text
            link = str(list(tttmp.select('a'))[0]).split("'")[1].replace('amp;','')
            
            result.append([name1, name2, name3, link ])
            
df_category = pd.DataFrame(result)
df_category
# Out:
#             0           1                2  \
# 0       푸드/헬스        가공식품          간편/즉석요리
# 1       푸드/헬스        가공식품            과자/간식
# 2       푸드/헬스        가공식품            김치/반찬
# 3       푸드/헬스        가공식품          라면/면/스프
# 4       푸드/헬스        가공식품        조미료/소스/장류
# 5       푸드/헬스        가공식품         커피/생수/음료
# 6       푸드/헬스        가공식품           탕/국/찌개
# 7       푸드/헬스   건강/다이어트식품             건강기능
# 8       푸드/헬스   건강/다이어트식품        다이어트/이너뷰티
# 9       푸드/헬스   건강/다이어트식품             전통건강
# 10      푸드/헬스   건강/다이어트식품               홍삼
# 11      푸드/헬스    농수축/신선식품               농산
# 12      푸드/헬스    농수축/신선식품               수산
# 13      푸드/헬스    농수축/신선식품               축산
# 14      푸드/헬스  가구/침구/인테리어             침실가구
# 15      푸드/헬스  가구/침구/인테리어             거실가구
# 16      푸드/헬스  가구/침구/인테리어             주방가구
# 17      푸드/헬스  가구/침구/인테리어             수납가구
# 18      푸드/헬스  가구/침구/인테리어         학생/사무용가구
# 19      푸드/헬스  가구/침구/인테리어             아동가구
# 20      푸드/헬스  가구/침구/인테리어           시공/DIY
# 21      푸드/헬스  가구/침구/인테리어        침구/커튼/카페트
# 22      푸드/헬스  가구/침구/인테리어            홈인테리어
# 23      푸드/헬스  가구/침구/인테리어             꽃/원예
# 24      푸드/헬스      가전/디지털       TV/냉장고/세탁기
# 25      푸드/헬스      가전/디지털             계절가전
# 26      푸드/헬스      가전/디지털  노트북/PC/태블릿/주변기기
# 27      푸드/헬스      가전/디지털         블랙박스/자동차
# 28      푸드/헬스      가전/디지털             생활가전
# 29      푸드/헬스      가전/디지털          영상/음향가전
# 30      푸드/헬스      가전/디지털          조리/가열기기
# 31      푸드/헬스      가전/디지털             주방가전
# 194     패션/뷰티   잡화/슈즈/쥬얼리             수입명품
# 195     패션/뷰티   잡화/슈즈/쥬얼리           쥬얼리/시계
# 196     패션/뷰티   잡화/슈즈/쥬얼리             패션슈즈
# 197     패션/뷰티        패션의류             여성의류
# 198     패션/뷰티        패션의류             남성의류
# 199     패션/뷰티        패션의류         캐주얼/유니섹스
# 200     패션/뷰티        패션의류             언더웨어
#
#                                                      3
# 0    CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 1    CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 2    CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 3    CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 4    CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 5    CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 6    CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 7    CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 8    CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 9    CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 10   CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 11   CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 12   CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 13   CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 14   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 15   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 16   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 17   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 18   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 19   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 20   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 21   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 22   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 23   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 24   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 25   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 26   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 27   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 28   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 29   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 30   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 31   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 32   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 33   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 34   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 35   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 36   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 37   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 38   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 39   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 40   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 41   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 42   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 43   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 44   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 45   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 46   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 47   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 48   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 49   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 50   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 51   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 52   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 53   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 54   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 55   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 56   CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 57   CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 58   CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 59   CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 60   CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 61   CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 62   CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 63   CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 64   CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 65   CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 66   CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 67   CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 68   CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 69   CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 70   CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 71   CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 72   CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 73   CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 74   CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 75   CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 76   CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 77   CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 78   CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 79   CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 80   CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 81   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 82   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 83   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 84   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 85   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 86   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 87   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 88   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 89   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 90   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 91   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 92   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 93   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 94   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 95   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 96   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 97   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 98   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 99   CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 100  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 101  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 102  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 103  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 104  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 105  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 106  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 107  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 108  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 109  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 110  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 111  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 112  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 113  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 114  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 115  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 116  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 117  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 118  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 119  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 120  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 121  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 122  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 123  CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 124  CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 125  CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 126  CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 127  CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 128  CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 129  CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 130  CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 131  CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 132  CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 133  CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 134  CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 135  CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 136  CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 137  CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 138  CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 139  CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 140  CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 141  CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 142  CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 143  CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 144  CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 145  CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 146  CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 147  CategoryDisplay?cate1Code=1583595&cate2Code=15...
# 148  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 149  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 150  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 151  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 152  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 153  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 154  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 155  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 156  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 157  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 158  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 159  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 160  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 161  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 162  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 163  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 164  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 165  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 166  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 167  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 168  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 169  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 170  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 171  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 172  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 173  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 174  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 175  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 176  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 177  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 178  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 179  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 180  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 181  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 182  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 183  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 184  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 185  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 186  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 187  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 188  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 189  CategoryDisplay?cate1Code=1583596&cate2Code=15...
# 190  CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 191  CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 192  CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 193  CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 194  CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 195  CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 196  CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 197  CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 198  CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 199  CategoryDisplay?cate1Code=1583594&cate2Code=15...
# 200  CategoryDisplay?cate1Code=1583594&cate2Code=15...

# %%
brand_list = []
for link in df_category[3] :
    new_url = url + link
    req = requests.get(new_url)
    html = req.text
    soup = BeautifulSoup(html, 'html.parser', from_encoding='utf-8')
    soup1 = list(soup.children)[3]
    body1 = list(soup1.children)[3]
    
    
    row_len = len(list(body1.select('#brandResultList > #result1 > p')))
    brand_name = []
    for row in range(row_len) : 
        x = list(body1.select('#brandResultList > #result1 > p'))[row]
        span_len = len(x.select('span.txt'))

        for span in range(span_len) :
            xx = x.select('span.txt')[span]
            brand_name.append(xx.text)
            
    brand_list.append(brand_name)

# %%
df_category['brand'] = brand_list
df_category
# Out:
#             0           1                2  \
# 0       푸드/헬스        가공식품          간편/즉석요리
# 1       푸드/헬스        가공식품            과자/간식
# 2       푸드/헬스        가공식품            김치/반찬
# 3       푸드/헬스        가공식품          라면/면/스프
# 4       푸드/헬스        가공식품        조미료/소스/장류
# 5       푸드/헬스        가공식품         커피/생수/음료
# 6       푸드/헬스        가공식품           탕/국/찌개
# 7       푸드/헬스   건강/다이어트식품             건강기능
# 8       푸드/헬스   건강/다이어트식품        다이어트/이너뷰티
# 185  [힐링타임, 히키스, 히로, 화이트크리너, 화이트랩스, 홈플리, 홈즈, 홈스타, 헬...
# 186  [힐링타임, 히키스, 효재, 홈앤하우스, 홈앤미, 홈스타, 해피타운, 해피맘, 한일...
# 187  [히키스, 흥덕산업, 휴크래프트, 휴센, 홈앤하우스, 홈앤미, 호두데코, 헬스마일,...
# 188  [힘멜, 힐링타임, 히키스, 히야신스, 히로코, 히든쉐프, 흥덕산업, 흥덕, 휘슬러...
# 189  [힐링타임, 히키스, 히비쿠, 홀튼, 호사, 호너, 현대오피스, 헬로키티, 헨리헬러...
# 190  [힐링타임, 휴스톰, 홈쇼핑브랜드, 헬스앤뷰티, 헬스마일, 헤드랑, 필립스코리아, ...
# 191  [힐링버드, 히말라야, 휴대용 러브젤증정, 휘엔느, 홈쇼핑브랜드, 헬스마일, 헤어코...
# 192  [히말라야, 휘욜라 비타민C 앰플, 휘욜라 비타민A 앰플, 휘엔느, 후즈후 코스메틱...
# 193  [힐링타임, 히키스, 휴크래프크, 휠팩, 호즈, 헬스마일, 헤드, 해당없음, 한스마...
# 194  [훌라, 피오렌티나, 플라우나, 프랑코푸치, 폴리스, 펀타스틱, 트레빌, 트래블나인...
# 195  [히어쉬, 호즈, 해밀턴, 한국금거래소, 하나통신, 프린코, 프리스카제이, 프레드릭...
# 196  [휠라, 홀스터, 헬스마일, 행텐, 핏플랍, 플러그티, 푸마, 포하스세로, 페이퍼플...
# 197  [홈쇼핑의류, 홈쇼핑상품, 홈쇼핑브랜드, 홈쇼핑, 헬리꽁땡, 하루메이비, 필로소피아...
# 198  [홈쇼핑의류, 홀리스터, 필로소피아, 필골드, 피크나인, 푸마, 폴스크릭, 폴로 랄...
# 199  [홀리스터, 필골드, 푸마, 포이, 패션지오, 파파브로, 티나리오, 텐제로, 탑보이...
# 200  [힐링타임, 히트클라인, 히트융, 히든토우, 훼르자, 화영사, 헨리코튼, 헤드언더웨...

# %%
#df_category = df_category.iloc[:,1:][:67]
df_category.iloc[14:56, 0] = '홈/라이프스타일'
df_category.iloc[56:, 0] = '패션/뷰티'

# %%
df_category.to_csv('./analysis/category.csv', encoding='cp949', index=False)

# %% [markdown]
# # brand

# %%
df_category = pd.read_csv('./analysis/category.csv', encoding='cp949')

# %%
brand_list = []
for i in range(len(df_category)) : 
    tmp = df_category['brand'][i][2:-2].split("', '")
    tmp_len = len(tmp)
    for j in range(tmp_len) :
        if tmp[j] in brand_list :
            pass
        else :
            brand_list.append(tmp[j])

# %%
df_category.columns = ['C1', 'C2', 'C3', 'link', 'brand']

# %% [markdown]
# # 분류 세분화

# %% [markdown]
# ## 대분류

# %%
C101 = [0]*len(brand_list)
C102 = [0]*len(brand_list)
C103 = [0]*len(brand_list)

# 푸드 / 헬스 
for i in range(14) :
    tmp = df_category['brand'][i][2:-2].split("', '")
    len_brand = len(tmp)
    for j in range(len_brand) :
        brand_idx = brand_list.index(tmp[j])
        C101[brand_idx] += 1

# # 홈 / 라이프스타일
for i in range(14, 56) :
    tmp = df_category['brand'][i][2:-2].split("', '")
    len_brand = len(tmp)
    for j in range(len_brand) :
        brand_idx = brand_list.index(tmp[j])
        C102[brand_idx] += 1
        
# # 패션 / 뷰티
for i in range(56, 67) :
    tmp = df_category['brand'][i][2:-2].split("', '")
    len_brand = len(tmp)
    for j in range(len_brand) :
        brand_idx = brand_list.index(tmp[j])
        C103[brand_idx] += 1

# %%
C101 = pd.DataFrame(C101)
C102 = pd.DataFrame(C102)
C103 = pd.DataFrame(C103)

x = pd.concat([C101, C102, C103], axis=1)
x.columns = ['food/health', 'home/life', 'fashion/beauty']

# %%
#x.to_excel('./analysis/tmp2.xlsx', encoding='cp949')

# %%
x.loc[15312,:].idxmax(axis=1)
# Out:
# 'fashion/beauty'

# %%
C1_result = []
for i in range(len(x)) :
    if i in [1061, 1625, 1054] : 
        # 모든 item을 하나씩 가지고 있는 경우 : index = [1061, 1625]
        # max 값이 동일한 경우 : [1054]
        C1_result.append('same')
    else :
        C1_result.append(x.loc[i,:].idxmax(axis=1))

# %%
C1_result = pd.DataFrame(C1_result)
brand_list = pd.DataFrame(brand_list)

result = pd.concat([brand_list, C1_result], axis=1)
result.columns = ['brand_list', 'C1_result']

# %%
result
# Out:
#        brand_list       C1_result
# 0             흰누리     food/health
# 1              흑심     food/health
# 2            효성어묵     food/health
# 3              화오     food/health
# 4             화과방     food/health
# ...           ...             ...
# 10093  BBC&IZUMI;  fashion/beauty
# 10094       BASIC  fashion/beauty
# 10095      365BUY  fashion/beauty
# 10096       (주)선우  fashion/beauty
# 10097    (주)남영비비안  fashion/beauty
#
# [10098 rows x 2 columns]

# %%
list(result['brand_list']).index('쿠첸')
# Out:
# 2359

# %% [markdown]
# # 정규식 사용하여 상품명 정리

# %%
df = pd.read_csv('./data/train_ongoing.csv', encoding='cp949')

# %% [markdown]
# ## SS, S, Q, K, SK /// S/S, F/W 정리

# %%
# 의류, 속옷, 잡화 중 SS 는 S/S로 변경
# FW는 F/W
def change_word(x) :
    if 'K-SWISS' not in x :
        x = x.replace('SS', 'S/S')
        x = x.replace('FW', 'F/W')
    return x
    
# 의류
tmp_idx = df.loc[(df['category']=='의류'),'product_name'].index
df.loc[(df['category']=='의류'),'product_name'] = list(map(change_word, df.loc[(df['category']=='의류'),'product_name']))

# 속옷
tmp_idx = df.loc[(df['category']=='속옷'),'product_name'].index
df.loc[(df['category']=='속옷'),'product_name'] = list(map(change_word, df.loc[(df['category']=='속옷'),'product_name']))

# 의류
tmp_idx = df.loc[(df['category']=='잡화'),'product_name'].index
df.loc[(df['category']=='잡화'),'product_name'] = list(map(change_word, df.loc[(df['category']=='잡화'),'product_name']))

# %%
# 가구, 침구 중 SS 는 슈퍼싱글로 변경
def eng_to_kor(x) :
    x = x.replace('SS', '슈퍼싱글')
    x = x.replace('S', '싱글')
    x = x.replace('Q', '퀸')
    x = x.replace('K', '킹')
    x = x.replace('SK', '싱글킹')
    return x

# 가구
tmp_idx = df.loc[(df['category']=='가구'),'product_name'].index
df.loc[(df['category']=='가구'),'product_name'] = list(map(eng_to_kor, df.loc[(df['category']=='가구'),'product_name']))

# 침구
tmp_idx = df.loc[(df['category']=='침구'),'product_name'].index
df.loc[(df['category']=='침구'),'product_name'] = list(map(eng_to_kor, df.loc[(df['category']=='침구'),'product_name']))

# %%
# df.to_excel('./analysis/tmp.xlsx', encoding='cp949')

# %% [markdown]
# ## 일시불, 무이자, 일), 무) 통일, 제거

# %%
def replace_word(x) :
    x = x.replace('무)', '무이자 ')
    x = x.replace('(무', '무')
    x = x.replace('일)', '일시불 ')
    x = x.replace('(일', '일')
    x = x.replace('(쿠)', '쿠첸')
    return x

brand_df = list(map(replace_word, df['product_name']))

# %%
def delete_word(x, word) :
    x = x.replace(word, '')
    return x

f = lambda x, y : delete_word(x, y)

for idx in range(len(brand_df)):
    brand_df[idx] = f(brand_df[idx], '일시불 ')
    brand_df[idx] = f(brand_df[idx], '무이자 ')
    brand_df[idx] = f(brand_df[idx], '일시불')
    brand_df[idx] = f(brand_df[idx], '무이자')

# %%
brand_df = pd.DataFrame(brand_df)
brand_df.columns = ['product_name']

# %% [markdown]
# ## 기획 (+,세트) 인기(~ 차, 시즌~)

# %%
## + , 세트
plus = []
for idx in range(len(brand_df)) :
    if '+' in brand_df['product_name'][idx] or '세트' in brand_df['product_name'][idx]:
        plus.append(1)
    else :
        plus.append(0)
        
brand_df = pd.DataFrame(brand_df)
brand_df['+'] = plus

# %%
# 3차
popular = []
for idx in range(len(brand_df)) : 
    text = brand_df['product_name'][idx]
    pattern = '[\d]*차'
    repl = ''
    after_text = re.sub(pattern = pattern, repl = repl, string = text)
    if text != after_text :
        popular.append(1)
        brand_df['product_name'][idx] = after_text
    else :
        popular.append(0)
# Out:
# C:\python\envs\cpu_env\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
# 시즌3
for idx in range(len(brand_df)) : 
    text = brand_df['product_name'][idx]
    
    pattern = '시즌[\d]+'
    repl = ''
    after_text = re.sub(pattern = pattern, repl = repl, string = text)
    
    if text != after_text :
        popular[idx] += 1
        brand_df['product_name'][idx] = after_text

        
# 시즌 3
for idx in range(len(brand_df)) : 
    text = brand_df['product_name'][idx]
    
    pattern = '시즌 [\d]+'
    repl = ''
    after_text = re.sub(pattern = pattern, repl = repl, string = text)
    
    if text != after_text :
        popular[idx] += 1
        brand_df['product_name'][idx] = after_text
        
brand_df = pd.DataFrame(brand_df)
brand_df['popular'] = popular
# Out:
# C:\python\envs\cpu_env\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\python\envs\cpu_env\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## attractive

# %%
## 초특가, 파격가, 세일, 100%, 국내산, 햇, 손질, 자연산, 무료, 체험

#####국내 다시 !!!!!
attractive = []
for idx in range(len(brand_df)) : 
    text = brand_df['product_name'][idx]
    pattern = "(초특가|파격가|세일|100%|국내산|햇|손질|자연산|무료|체험|국내제작|국내용|국내)" 
    repl = ''
    after_text = re.sub(pattern = pattern, repl = repl, string = text)
    if text != after_text :
        attractive.append(1)
        brand_df['product_name'][idx] = after_text
    else :
        attractive.append(0)
    
brand_df = pd.DataFrame(brand_df)
brand_df['attractive'] = attractive
# Out:
# C:\python\envs\cpu_env\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %% [markdown]
# ## 단위가 붙은 상품명
#
# : 종, 봉, 개, 단, 박스, 형, 팩, 세트, 대, 구, 인용, 인분, 과, 장, 미, 마리, 매, kg, L, g, 도

# %%
for idx in range(len(brand_df)) : 
    
    text = brand_df['product_name'][idx]
    
    pattern = "[\d]+(종|봉|개|단|박스|형|팩|세트|대|구|인용|인분|과|장|미|마리|매|kg|Kg|L|g|도|병|주분|일분|포|통|m|P|CH|주|롤|등급|월)" 
    repl = ''
    after_text = re.sub(pattern = pattern, repl = repl, string = text)
    
    brand_df['product_name'][idx] = after_text
# Out:
# C:\python\envs\cpu_env\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# ## 색상 제거

# %%
for idx in range(len(brand_df)) : 
    text = brand_df['product_name'][idx]
    
    pattern = '(블랙|실버|화이트|레드)'
    repl = ''    
    brand_df['product_name'][idx] = re.sub(pattern = pattern, repl = repl, string = text)
# Out:
# C:\python\envs\cpu_env\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## 성별 제거

# %%
for idx in range(len(brand_df)) : 
    text = brand_df['product_name'][idx]
    
    pattern = '(남성|여성|유아)'
    repl = ''    
    brand_df['product_name'][idx] = re.sub(pattern = pattern, repl = repl, string = text)
# Out:
# C:\python\envs\cpu_env\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## S/S , F/W
#
# 2018 , 2019 안나뉜 상태

# %%
season = []
for idx in range(len(brand_df)) : 
    text = brand_df['product_name'][idx]
    
    if 'S/S' in text :
        season.append(1)
    elif 'F/W' in text :
        season.append(2)
    else :
        season.append(0)


brand_df['new'] = season

# %% [markdown]
# ## 상품 종류 _형

# %%
for idx in range(len(brand_df)) : 
    text = brand_df['product_name'][idx]
        
    pattern = '(수납|멀티수납|기본|하부장|고급|2IN1|스탠드|대|소|일체|점보특대|점보|중|손목|조끼|긴팔|런닝|끈|티셔츠|프리미엄|2019년|특대|슈퍼특대)[형]'
    repl = ''    
    brand_df['product_name'][idx] = re.sub(pattern = pattern, repl = repl, string = text)
# Out:
# C:\python\envs\cpu_env\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# - 멀티수납, 기본, 하부장, 

# 가전 : 기본, 고급, 2IN1, 스탠드, (숫자)

# 생활용품 : 대, 소, 일체, 점보특대, 점보, 중, 손목

# 속옷 : 조끼, 긴팔, 런닝, 끈, 티셔츠

# 주방 : 프리미엄, 기본, 고급, 대, 2019년형

# 침구 : 중, 대, 특대, 슈퍼특대, 점보특대,

# %%
# brand_df.to_excel('./analysis/product_name.xlsx', encoding='cp949')

# %% [markdown]
# # 정규식  연습

# %%
 
text = "123ㄴㅇ리ㅏasdflskjfl 아sdf에sdf이sd오!!우))()!"

'국내(제작|생산|산|)'
pattern = '^[\d]+차 | 시즌[\d+]'
pattern = "(초특가|파격가|세일|100%|국내산|햇|손질|자연산|무료|체험)" 
pattern = "[\d]+(종|봉|개|단|박스|형|팩|세트|대|구|인용|인분|과|장|미|마리|매|kg|Kg|L|g|도)" 
pattern = '[^가-힣]'

repl = ''

re.sub(pattern = pattern, repl = repl, string = text)
# Out:
# '리아에이오우'

# %%
## 종, 봉, 개, 단, 박스, 형, 팩, 세트, 대, 구, 인용, 인분, 과, 장, 미, 마리, 매, kg, L, g, 도

text = "스탠드형 수납형 몰라형"

pattern = '(멀티수납|기본|하부장|고급|2IN1|스탠드|대|소|일체|점보특대|점보|중|손목|조끼|긴팔|런닝|끈|티셔츠|프리미엄|2019년|특대|슈퍼특대)[형]'
repl = ''


re.sub(pattern = pattern, repl = repl, string = text)
# Out:
# ' 수납형 몰라형'
