# %% [markdown]
# # 데이터 정제

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import pandas as pd
import numpy as np
from datetime import datetime
import time

# 한글 폰트 설정

fm.get_fontconfig_fonts()
font_location = 'C:/Windows/Fonts/NanumGothic.ttf' # For Windows
font_name = fm.FontProperties(fname=font_location).get_name()
plt.rc('font', family=font_name)
plt.rc('font', size=20)

# 지수 표현 안보기

# %%
# 데이터 로드
data = pd.read_csv('data/train.csv', encoding='cp949', header=0, parse_dates=["방송일시"])

# 상품군 = 무형 제거 

data.drop(data[data['상품군']=='무형'].index, inplace=True)
data.reset_index(inplace=True)


# 판매단가, 취급액 쉼표 제거 , int 변환

data['판매단가'] = data['판매단가'].str.replace(',','').astype(int)
data[' 취급액 '] = data[' 취급액 '].str.replace(',','').astype(int)
data['노출(분)'] = data['노출(분)'].astype(int)


# 방송일시 column 분리 ( , 일, 시, 분, 요일 )

data['방송일시'] = pd.to_datetime(data['방송일시'], format='%Y-%m-%d %H:%M:%S', errors='raise')

data['month'] = data['방송일시'].dt.month
data['day'] = data['방송일시'].dt.day
data['hour'] = data['방송일시'].dt.hour
data['minute'] = data['방송일시'].dt.minute
data['요일'] = data['방송일시'].dt.weekday

# 06 ~ 익일 02 가 한 cycle임을 고려하여 0, 1, 2 에 +24를 해주자

# def plus_24(x) :
#     if x in [0, 1, 2] :
#         return x + 24
#     else :
#         return x
    
# data['hour'] = list(map(plus_24, data['hour']))
overnight_index_list = data.loc[(data["hour"] >=0) & (data["hour"] < 3)].index

overnight_index_list
data.loc[overnight_index_list, "hour"] += 24
data.loc[overnight_index_list, "day"] -= 1
data.loc[overnight_index_list, "요일"] -= 1
data.loc[data["요일"] == -1, "요일"] = 6

# %% [markdown]
# # 상품명에 있는 키워드로 살펴보자

# %% [markdown]
# ## 햇

# %% [markdown]
# * 특정 키워드를 추출해서 어떤걸 확인해보지 ???
#
# - 노출시간에 따라 취급액을 확인했더니 11분일 때 취급액이 매우크다.
#
# -> 확인 결과 '햇' 단어 확인
# ![image.png](attachment:image.png)
#
# ->  '햇' 단어가 든 상품 / 아닌 것 비교해보자
#
# ---
# ---
# ---
# ---
# ---
# 노출시간을 먼저 합해줘야하나 ????? pending !!!!!!!!

# %%
idx = []
for i in range(len(df['상품명'])) : 
    if '햇' in df['상품명'][i] :
        idx.append(i)

# '햇'글자 포함(185row)
print(df.iloc[idx].mean())
# '햇'글자 제외
print(df.drop(idx).mean())


## 주의 : '햇' 단어에 햇반?과 같은 단어 있는지 확인 (test set)
## 결과 : 판매단가가 비슷, 노출시간은 '햇' 단어 제외가 더 많음, 취급액은 '햇'포함이 훨씬 높음
## + ) 당연한 것 같기도하고 ???????????????????
## 아닌가????????????
# Out:
# month       1.044324e+01
# day         1.736216e+01
# hour        1.690811e+01
# minute      1.967568e+01
# 요일          3.383784e+00
# 마더코드        1.003487e+05
# 상품코드        2.013257e+05
# 노출(분)       1.962162e+01
# 판매단가        4.990000e+04
#  취급액        6.551279e+07
# pay_type    0.000000e+00
# dtype: float64
# month       6.443461e+00
# day         1.527676e+01
# hour        1.630594e+01
# minute      2.007287e+01
# 요일          3.015973e+00
# 마더코드        1.003897e+05
# 상품코드        2.012113e+05
# 노출(분)       2.038546e+01
# 판매단가        4.700806e+05
#  취급액        2.165595e+07
# pay_type    5.793422e-01
# dtype: float64

# %% [markdown]
# # 노출 시간 ( 같은 제품 하루에 4번 이상 노출 )
#
# 같은 제품을 연속적으로 방송해서 편성표에 3번 * 2번 배치된 것도 있고 : 3 / 22 . 200889 ( 20분씩 편성됨 )
#
# 같은 제품인데 시간을 다르게 해서 편성표에 6번 로 배치된 것도 있다 : 12 / 22 , 200153 ( 10분씩 편성됨 )

# %% [markdown]
# month, day가 같은데 상품코드가 같다면 ? ( 여기에 일시불 , 무이자 / 몇인용 그런거 다 포함 된거임 )
#
# => 이걸로 하면 안됨 => 하루에 상품을 여러 시간대에 배치하는 경우가 있음

# %% [markdown]
# ## 노출(분) 데이터 뜯어보자

# %%
## 단순 편성 개수 ( 연달아 있는거 있음 주의 )
df['노출(분)'].value_counts()
# Out:
# 20    33057
# 30     2625
# 10      813
# 15      453
# 17      161
# 16      117
# 13       67
# 26       12
# 25       11
# 23        9
# 18        6
# 7         6
# 3         6
# 12        5
# 5         5
# 22        4
# 11        4
# 19        3
# 27        2
# 14        2
# 40        2
# 9         1
# 2         1
# Name: 노출(분), dtype: int64

# %%
# 편성 개수 대비 취급액 평균이 높은 것
df[' 취급액 '].groupby(df['노출(분)']).mean().sort_values(ascending=False)
# Out:
# 노출(분)
# 11    5.644025e+07
# 18    2.792483e+07
# 27    2.589550e+07
# 20    2.228159e+07
# 30    2.144906e+07
# 19    2.139367e+07
# 7     1.809683e+07
# 10    1.699862e+07
# 14    1.680200e+07
# 22    1.668525e+07
# 17    1.485490e+07
# 13    1.269301e+07
# 26    1.165175e+07
# 15    1.132159e+07
# 23    1.107933e+07
# 2     1.073100e+07
# 12    1.070180e+07
# 40    1.014050e+07
# 3     1.013067e+07
# 25    9.765273e+06
# 16    9.693538e+06
# 5     7.447000e+06
# 9     9.710000e+05
# Name:  취급액 , dtype: float64

# %%
df.loc[df['노출(분)']==11]
# Out:
#        month  day  hour  minute  노출(분)    상품코드                    상품명   판매단가  \
# 30547     10   20    16      40     11  201486  피시원 국내산 절단 햇 꽃게 2.4kg  49900
# 31204     10   27    16      40     11  201486  피시원 국내산 절단 햇 꽃게 2.4kg  49900
# 34881     12    5    21       0     11  201004       국내산 손질 햇 갑오징어 9팩  49900
# 35806     12   14    17      20     11  201634          완도꼬마활전복 1.3kg  29900
#
#            취급액   요일  상품군    마더코드  pay_type
# 30547  53796000   6  농수축  100492         0
# 31204  82924000   6  농수축  100492         0
# 34881  47069000   3  농수축  100317         0
# 35806  41972000   5  농수축  100548         0

# %%
# 취급액 최대값인 노출시간
df[' 취급액 '].groupby(df['노출(분)']).max().sort_values(ascending=False)
# Out:
# 노출(분)
# 17    322009000
# 20    270284000
# 30    153959000
# 13    108590000
# 10     84950000
# 11     82924000
# 18     76905000
# 7      63269000
# 15     55655000
# 16     41859000
# 25     33264000
# 3      30798000
# 27     29034000
# 26     26273000
# 19     24885000
# 22     24475000
# 23     22171000
# 12     20502000
# 14     17818000
# 40     16770000
# 5      16426000
# 2      10731000
# 9        971000
# Name:  취급액 , dtype: int64

# %% [markdown]
# ## 노출(분)과 편성 개수 관계

# %%
tmp = df.groupby(['month','day','상품코드']).sum()[' 취급액 ']
tmp2 = df.groupby(['month','day','상품코드']).count()[' 취급액 ']

# %%
x = []
for i in tmp.index :
    print('취급액 : ', tmp[i], '개수 : ', tmp2[i])
    if tmp2[i] in [4,5,6,8,9,10,12] : 
        x.append(i)
        if tmp2[i] == 6:
            print('------------------------------------------------',i)

# tmp[x].to_excel('./analysis/하루안에상품여러번판매.xlsx', encoding='cp949')
# Out:
# 취급액 :  222836000 개수 :  3
# 취급액 :  192141000 개수 :  3
# 취급액 :  123876000 개수 :  3
# 취급액 :  160698000 개수 :  3
# 취급액 :  43858000 개수 :  3
# 취급액 :  115831000 개수 :  2
# 취급액 :  111546000 개수 :  2
# 취급액 :  47878000 개수 :  3
# 취급액 :  12033000 개수 :  3
# 취급액 :  20663000 개수 :  3
# 취급액 :  51795000 개수 :  2
# 취급액 :  34528000 개수 :  3
# 취급액 :  68135000 개수 :  2
# 취급액 :  25577000 개수 :  3
# 취급액 :  246455000 개수 :  3
# 취급액 :  176244000 개수 :  2
# 취급액 :  86177000 개수 :  3
# 취급액 :  190579000 개수 :  3
# 취급액 :  74360000 개수 :  2
# 취급액 :  154715000 개수 :  3
# 취급액 :  122537000 개수 :  3
# 취급액 :  99736000 개수 :  3
# 취급액 :  259678000 개수 :  3
# 취급액 :  90973000 개수 :  3
# 취급액 :  83893000 개수 :  1
# 취급액 :  10574000 개수 :  3
# 취급액 :  30986000 개수 :  3
# 취급액 :  14623000 개수 :  3
# 취급액 :  47841000 개수 :  3
# 취급액 :  12659000 개수 :  3
# 취급액 :  82649000 개수 :  3
# 취급액 :  150000 개수 :  3
# 취급액 :  61526000 개수 :  3
# 취급액 :  35241000 개수 :  3
# 취급액 :  101053000 개수 :  3
# 취급액 :  155211000 개수 :  3
# 취급액 :  96155000 개수 :  2
# 취급액 :  85256000 개수 :  2
# 취급액 :  67533000 개수 :  3
# 취급액 :  70951000 개수 :  3
# 취급액 :  17810000 개수 :  2
# 취급액 :  34570000 개수 :  2
# 취급액 :  74098000 개수 :  3
# 취급액 :  128485000 개수 :  3
# 취급액 :  6026000 개수 :  3
# 취급액 :  9321000 개수 :  3
# 취급액 :  55443000 개수 :  3
# 취급액 :  112405000 개수 :  3
# 취급액 :  106570000 개수 :  3
# 취급액 :  40950000 개수 :  3
# 취급액 :  10137000 개수 :  3
# 취급액 :  78940000 개수 :  3
# 취급액 :  24550000 개수 :  3
# 취급액 :  27619000 개수 :  3
# 취급액 :  47845000 개수 :  3
# 취급액 :  18480000 개수 :  3
# 취급액 :  53370000 개수 :  3
# 취급액 :  11583000 개수 :  3
# 취급액 :  41430000 개수 :  3
# 취급액 :  130196000 개수 :  3
# 취급액 :  112947000 개수 :  3
# 취급액 :  116724000 개수 :  3
# 취급액 :  31423000 개수 :  3
# 취급액 :  46430000 개수 :  3
# 취급액 :  7399000 개수 :  3
# 취급액 :  25217000 개수 :  3
# 취급액 :  45969000 개수 :  3
# 취급액 :  19738000 개수 :  3
# 취급액 :  48878000 개수 :  3
# 취급액 :  119902000 개수 :  3
# 취급액 :  102903000 개수 :  2
# 취급액 :  88529000 개수 :  3
# 취급액 :  39733000 개수 :  3
# 취급액 :  39929000 개수 :  3
# 취급액 :  76649000 개수 :  3
# 취급액 :  232596000 개수 :  3
# 취급액 :  82616000 개수 :  3
# 취급액 :  73259000 개수 :  3
# 취급액 :  71433000 개수 :  3
# 취급액 :  13897000 개수 :  3
# 취급액 :  10129000 개수 :  3
# 취급액 :  57383000 개수 :  3
# 취급액 :  148904000 개수 :  3
# 취급액 :  87262000 개수 :  3
# 취급액 :  76661000 개수 :  3
# 취급액 :  12681000 개수 :  3
# 취급액 :  17104000 개수 :  3
# 취급액 :  84789000 개수 :  3
# 취급액 :  134221000 개수 :  3
# 취급액 :  61373000 개수 :  3
# 취급액 :  13447000 개수 :  3
# 취급액 :  14227000 개수 :  3
# 취급액 :  59276000 개수 :  3
# 취급액 :  161417000 개수 :  3
# 취급액 :  82568000 개수 :  3
# 취급액 :  86664000 개수 :  3
# 취급액 :  122899000 개수 :  3
# 취급액 :  58478000 개수 :  3
# 취급액 :  67545000 개수 :  2
# 취급액 :  111035000 개수 :  3
# 취급액 :  125512000 개수 :  3
# 취급액 :  92222000 개수 :  3
# 취급액 :  79745000 개수 :  2
# 취급액 :  30913000 개수 :  3
# 취급액 :  65816000 개수 :  3
# 취급액 :  85009000 개수 :  2
# 취급액 :  87263000 개수 :  3
# 취급액 :  10166000 개수 :  1
# 취급액 :  55851000 개수 :  3
# 취급액 :  46295000 개수 :  3
# 취급액 :  140992000 개수 :  3
# 취급액 :  71174000 개수 :  3
# 취급액 :  112617000 개수 :  3
# 취급액 :  62837000 개수 :  3
# 취급액 :  14922000 개수 :  3
# 취급액 :  43257000 개수 :  3
# 취급액 :  5534000 개수 :  3
# 취급액 :  27402000 개수 :  3
# 취급액 :  59016000 개수 :  3
# 취급액 :  11236000 개수 :  3
# 취급액 :  14937000 개수 :  3
# 취급액 :  49659000 개수 :  3
# 취급액 :  115409000 개수 :  3
# 취급액 :  132733000 개수 :  3
# 취급액 :  173551000 개수 :  3
# 취급액 :  34938000 개수 :  3
# 취급액 :  87642000 개수 :  3
# 취급액 :  21872000 개수 :  3
# 취급액 :  76541000 개수 :  3
# 취급액 :  28295000 개수 :  3
# 취급액 :  78042000 개수 :  3
# 취급액 :  19739000 개수 :  3
# 취급액 :  68255000 개수 :  3
# 취급액 :  30218000 개수 :  3
# 취급액 :  19209000 개수 :  3
# 취급액 :  155117000 개수 :  3
# 취급액 :  70159000 개수 :  3
# 취급액 :  23214000 개수 :  3
# 취급액 :  35108000 개수 :  3
# 취급액 :  94162000 개수 :  2
# 취급액 :  131746000 개수 :  2
# 취급액 :  55476000 개수 :  3
# 취급액 :  233851000 개수 :  3
# 취급액 :  70892000 개수 :  3
# 취급액 :  11951000 개수 :  3
# 취급액 :  7168000 개수 :  3
# 취급액 :  171008000 개수 :  3
# 취급액 :  48644000 개수 :  3
# 취급액 :  13476000 개수 :  3
# 취급액 :  87694000 개수 :  3
# 취급액 :  31393000 개수 :  3
# 취급액 :  118333000 개수 :  3
# 취급액 :  76992000 개수 :  2
# 취급액 :  153801000 개수 :  3
# 취급액 :  81471000 개수 :  3
# 취급액 :  178901000 개수 :  3
# 취급액 :  164256000 개수 :  3
# 취급액 :  66822000 개수 :  3
# 취급액 :  90913000 개수 :  3
# 취급액 :  190234000 개수 :  3
# 취급액 :  13874000 개수 :  3
# 취급액 :  14515000 개수 :  3
# 취급액 :  69034000 개수 :  3
# 취급액 :  112751000 개수 :  2
# 취급액 :  107504000 개수 :  3
# 취급액 :  140001000 개수 :  2
# 취급액 :  127460000 개수 :  3
# 취급액 :  83659000 개수 :  2
# 취급액 :  226973000 개수 :  3
# 취급액 :  199477000 개수 :  3
# 취급액 :  84623000 개수 :  3
# 취급액 :  14507000 개수 :  3
# 취급액 :  10160000 개수 :  3
# 취급액 :  43768000 개수 :  3
# 취급액 :  80990000 개수 :  3
# 취급액 :  129417000 개수 :  3
# 취급액 :  35515000 개수 :  3
# 취급액 :  14060000 개수 :  3
# 취급액 :  77749000 개수 :  3
# 취급액 :  29667000 개수 :  3
# 취급액 :  128563000 개수 :  3
# 취급액 :  73127000 개수 :  3
# 취급액 :  79173000 개수 :  3
# 취급액 :  16410000 개수 :  3
# 취급액 :  14227000 개수 :  3
# 취급액 :  60014000 개수 :  3
# 취급액 :  85181000 개수 :  3
# 취급액 :  126381000 개수 :  3
# 취급액 :  90671000 개수 :  3
# 취급액 :  96577000 개수 :  3
# 취급액 :  23043000 개수 :  3
# 취급액 :  103179000 개수 :  3
# 취급액 :  51587000 개수 :  3
# 취급액 :  22376000 개수 :  3
# 취급액 :  132025000 개수 :  3
# 취급액 :  104065000 개수 :  3
# 취급액 :  97413000 개수 :  2
# 취급액 :  55597000 개수 :  2
# 취급액 :  202243000 개수 :  3
# 취급액 :  158668000 개수 :  3
# 취급액 :  5720000 개수 :  3
# 취급액 :  7251000 개수 :  3
# 취급액 :  47243000 개수 :  3
# 취급액 :  94747000 개수 :  3
# 취급액 :  100098000 개수 :  3
# 취급액 :  17822000 개수 :  3
# 취급액 :  40935000 개수 :  3
# 취급액 :  16941000 개수 :  3
# 취급액 :  28104000 개수 :  3
# 취급액 :  55315000 개수 :  3
# 취급액 :  39998000 개수 :  3
# 취급액 :  46647000 개수 :  3
# 취급액 :  15686000 개수 :  3
# 취급액 :  14923000 개수 :  3
# 취급액 :  40810000 개수 :  3
# 취급액 :  134923000 개수 :  3
# 취급액 :  27957000 개수 :  3
# 취급액 :  67035000 개수 :  3
# 취급액 :  14598000 개수 :  3
# 취급액 :  6404000 개수 :  3
# 취급액 :  78067000 개수 :  3
# 취급액 :  13193000 개수 :  3
# 취급액 :  134611000 개수 :  3
# 취급액 :  30450000 개수 :  3
# 취급액 :  19855000 개수 :  3
# 취급액 :  30011000 개수 :  3
# 취급액 :  102850000 개수 :  2
# 취급액 :  78037000 개수 :  3
# 취급액 :  215465000 개수 :  3
# 취급액 :  108120000 개수 :  3
# 취급액 :  74475000 개수 :  3
# 취급액 :  11546000 개수 :  3
# 취급액 :  7917000 개수 :  3
# 취급액 :  94711000 개수 :  3
# 취급액 :  87668000 개수 :  3
# 취급액 :  28451000 개수 :  3
# 취급액 :  8461000 개수 :  3
# 취급액 :  68159000 개수 :  3
# 취급액 :  21897000 개수 :  3
# 취급액 :  45527000 개수 :  3
# 취급액 :  77593000 개수 :  3
# 취급액 :  63618000 개수 :  2
# 취급액 :  113015000 개수 :  3
# 취급액 :  117340000 개수 :  3
# 취급액 :  59804000 개수 :  3
# 취급액 :  16410000 개수 :  3
# 취급액 :  17041000 개수 :  3
# 취급액 :  56313000 개수 :  3
# 취급액 :  108199000 개수 :  3
# 취급액 :  132913000 개수 :  3
# 취급액 :  118018000 개수 :  3
# 취급액 :  108154000 개수 :  2
# 취급액 :  70050000 개수 :  3
# 취급액 :  81066000 개수 :  3
# 취급액 :  57947000 개수 :  3
# 취급액 :  50947000 개수 :  3
# 취급액 :  122270000 개수 :  3
# 취급액 :  108760000 개수 :  3
# 취급액 :  59236000 개수 :  2
# 취급액 :  61274000 개수 :  3
# 취급액 :  149686000 개수 :  3
# 취급액 :  166109000 개수 :  3
# 취급액 :  26146000 개수 :  3
# 취급액 :  10136000 개수 :  3
# 취급액 :  59362000 개수 :  3
# 취급액 :  20836000 개수 :  3
# 취급액 :  125483000 개수 :  3
# 취급액 :  91804000 개수 :  3
# 취급액 :  9308000 개수 :  3
# 취급액 :  37129000 개수 :  3
# 취급액 :  9531000 개수 :  3
# 취급액 :  25980000 개수 :  3
# 취급액 :  90972000 개수 :  3
# 취급액 :  128484000 개수 :  3
# 취급액 :  29368000 개수 :  3
# 취급액 :  109771000 개수 :  3
# 취급액 :  145623000 개수 :  3
# 취급액 :  38381000 개수 :  3
# 취급액 :  67036000 개수 :  3
# 취급액 :  7374000 개수 :  3
# 취급액 :  25193000 개수 :  3
# 취급액 :  64322000 개수 :  3
# 취급액 :  13192000 개수 :  3
# 취급액 :  73765000 개수 :  3
# 취급액 :  64374000 개수 :  3
# 취급액 :  140716000 개수 :  3
# 취급액 :  93260000 개수 :  3
# 취급액 :  120600000 개수 :  3
# 취급액 :  29111000 개수 :  3
# 취급액 :  58416000 개수 :  2
# 취급액 :  118001000 개수 :  3
# 취급액 :  70015000 개수 :  3
# 취급액 :  184514000 개수 :  3
# 취급액 :  90355000 개수 :  3
# 취급액 :  121508000 개수 :  3
# 취급액 :  131690000 개수 :  3
# 취급액 :  28523000 개수 :  3
# 취급액 :  6299000 개수 :  3
# 취급액 :  68178000 개수 :  3
# 취급액 :  25096000 개수 :  3
# 취급액 :  14387000 개수 :  3
# 취급액 :  24820000 개수 :  3
# 취급액 :  43676000 개수 :  3
# 취급액 :  18479000 개수 :  3
# 취급액 :  52513000 개수 :  3
# 취급액 :  14201000 개수 :  3
# 취급액 :  33279000 개수 :  3
# 취급액 :  106158000 개수 :  3
# 취급액 :  108246000 개수 :  3
# 취급액 :  47841000 개수 :  3
# 취급액 :  43481000 개수 :  3
# 취급액 :  111728000 개수 :  3
# 취급액 :  78853000 개수 :  3
# 취급액 :  23951000 개수 :  3
# 취급액 :  14410000 개수 :  3
# 취급액 :  79514000 개수 :  2
# 취급액 :  67765000 개수 :  2
# 취급액 :  66164000 개수 :  3
# 취급액 :  62470000 개수 :  3
# 취급액 :  17769000 개수 :  3
# 취급액 :  22624000 개수 :  3
# 취급액 :  24210000 개수 :  3
# 취급액 :  20752000 개수 :  3
# 취급액 :  114365000 개수 :  2
# 취급액 :  64168000 개수 :  3
# 취급액 :  9326000 개수 :  3
# 취급액 :  38087000 개수 :  3
# 취급액 :  28213000 개수 :  3
# 취급액 :  130476000 개수 :  3
# 취급액 :  53246000 개수 :  3
# 취급액 :  155363000 개수 :  3
# 취급액 :  89775000 개수 :  3
# 취급액 :  151484000 개수 :  3
# 취급액 :  153395000 개수 :  3
# 취급액 :  110642000 개수 :  3
# 취급액 :  37322000 개수 :  3
# 취급액 :  10490000 개수 :  3
# 취급액 :  10708000 개수 :  3
# 취급액 :  29706000 개수 :  3
# 취급액 :  121465000 개수 :  3
# 취급액 :  109842000 개수 :  3
# 취급액 :  153222000 개수 :  3
# 취급액 :  34914000 개수 :  3
# 취급액 :  31011000 개수 :  3
# 취급액 :  7399000 개수 :  3
# 취급액 :  47205000 개수 :  3
# 취급액 :  32224000 개수 :  3
# 취급액 :  13192000 개수 :  3
# 취급액 :  114778000 개수 :  2
# 취급액 :  50947000 개수 :  3
# 취급액 :  16478000 개수 :  3
# 취급액 :  102837000 개수 :  3
# 취급액 :  30006000 개수 :  3
# 취급액 :  100776000 개수 :  2
# 취급액 :  61891000 개수 :  3
# 취급액 :  53695000 개수 :  3
# 취급액 :  103442000 개수 :  2
# 취급액 :  129060000 개수 :  3
# 취급액 :  48339000 개수 :  3
# 취급액 :  35469000 개수 :  3
# 취급액 :  137468000 개수 :  3
# 취급액 :  73709000 개수 :  3
# 취급액 :  11104000 개수 :  3
# 취급액 :  6743000 개수 :  3
# 취급액 :  80134000 개수 :  3
# 취급액 :  88251000 개수 :  2
# 취급액 :  106313000 개수 :  3
# 취급액 :  17105000 개수 :  3
# 취급액 :  63475000 개수 :  3
# 취급액 :  17610000 개수 :  3
# 취급액 :  28908000 개수 :  3
# 취급액 :  105743000 개수 :  3
# 취급액 :  108061000 개수 :  3
# 취급액 :  67126000 개수 :  3
# 취급액 :  83829000 개수 :  3
# 취급액 :  17148000 개수 :  3
# 취급액 :  17033000 개수 :  3
# 취급액 :  78491000 개수 :  3
# 취급액 :  344551000 개수 :  6
# ------------------------------------------------ (1, 13, 200197)
# 취급액 :  191786000 개수 :  3
# 취급액 :  73246000 개수 :  3
# 취급액 :  116699000 개수 :  3
# 취급액 :  3672000 개수 :  2
# 취급액 :  5701000 개수 :  2
# 취급액 :  26390000 개수 :  2
# 취급액 :  4981000 개수 :  2
# 취급액 :  12268000 개수 :  2
# 취급액 :  47050000 개수 :  2
# 취급액 :  38593000 개수 :  3
# 취급액 :  67855000 개수 :  3
# 취급액 :  83714000 개수 :  2
# 취급액 :  110029000 개수 :  2
# 취급액 :  90721000 개수 :  2
# 취급액 :  13613000 개수 :  3
# 취급액 :  14870000 개수 :  3
# 취급액 :  136106000 개수 :  3
# 취급액 :  126472000 개수 :  3
# 취급액 :  243162000 개수 :  3
# 취급액 :  106047000 개수 :  2
# 취급액 :  132587000 개수 :  3
# 취급액 :  32263000 개수 :  3
# 취급액 :  24504000 개수 :  3
# 취급액 :  6722000 개수 :  3
# 취급액 :  6423000 개수 :  3
# 취급액 :  65762000 개수 :  3
# 취급액 :  25662000 개수 :  3
# 취급액 :  6285000 개수 :  3
# 취급액 :  66071000 개수 :  3
# 취급액 :  21902000 개수 :  3
# 취급액 :  155124000 개수 :  2
# 취급액 :  49639000 개수 :  3
# 취급액 :  20600000 개수 :  3
# 취급액 :  76360000 개수 :  3
# 취급액 :  20257000 개수 :  3
# 취급액 :  53154000 개수 :  3
# 취급액 :  57468000 개수 :  3
# 취급액 :  85348000 개수 :  3
# 취급액 :  73369000 개수 :  3
# 취급액 :  146609000 개수 :  3
# 취급액 :  82949000 개수 :  3
# 취급액 :  121945000 개수 :  3
# 취급액 :  97769000 개수 :  3
# 취급액 :  113196000 개수 :  2
# 취급액 :  38860000 개수 :  3
# 취급액 :  30145000 개수 :  3
# 취급액 :  90629000 개수 :  2
# 취급액 :  251633000 개수 :  3
# 취급액 :  128207000 개수 :  3
# 취급액 :  71647000 개수 :  3
# 취급액 :  93998000 개수 :  3
# 취급액 :  13553000 개수 :  3
# 취급액 :  23310000 개수 :  3
# 취급액 :  8196000 개수 :  3
# 취급액 :  16350000 개수 :  3
# 취급액 :  64635000 개수 :  3
# 취급액 :  91096000 개수 :  3
# 취급액 :  134228000 개수 :  3
# 취급액 :  70647000 개수 :  3
# 취급액 :  21587000 개수 :  3
# 취급액 :  17023000 개수 :  3
# 취급액 :  56292000 개수 :  3
# 취급액 :  122742000 개수 :  3
# 취급액 :  146981000 개수 :  3
# 취급액 :  102621000 개수 :  3
# 취급액 :  31375000 개수 :  3
# 취급액 :  56708000 개수 :  3
# 취급액 :  14648000 개수 :  3
# 취급액 :  31472000 개수 :  3
# 취급액 :  36854000 개수 :  3
# 취급액 :  26260000 개수 :  3
# 취급액 :  93990000 개수 :  3
# 취급액 :  148975000 개수 :  3
# 취급액 :  18916000 개수 :  3
# 취급액 :  40442000 개수 :  3
# 취급액 :  51460000 개수 :  3
# 취급액 :  13617000 개수 :  3
# 취급액 :  14791000 개수 :  3
# 취급액 :  23082000 개수 :  3
# 취급액 :  29871000 개수 :  3
# 취급액 :  45111000 개수 :  3
# 취급액 :  35313000 개수 :  3
# 취급액 :  65352000 개수 :  2
# 취급액 :  121083000 개수 :  3
# 취급액 :  15443000 개수 :  3
# 취급액 :  81169000 개수 :  3
# 취급액 :  13830000 개수 :  3
# 취급액 :  122101000 개수 :  3
# 취급액 :  46211000 개수 :  3
# 취급액 :  48295000 개수 :  3
# 취급액 :  154737000 개수 :  3
# 취급액 :  28099000 개수 :  3
# 취급액 :  12398000 개수 :  3
# 취급액 :  69506000 개수 :  3
# 취급액 :  22995000 개수 :  3
# 취급액 :  17774000 개수 :  3
# 취급액 :  41809000 개수 :  3
# 취급액 :  15470000 개수 :  3
# 취급액 :  34098000 개수 :  3
# 취급액 :  137454000 개수 :  3
# 취급액 :  123136000 개수 :  3
# 취급액 :  122606000 개수 :  3
# 취급액 :  72688000 개수 :  3
# 취급액 :  104213000 개수 :  3
# 취급액 :  82700000 개수 :  3
# 취급액 :  55858000 개수 :  3
# 취급액 :  93811000 개수 :  3
# 취급액 :  54308000 개수 :  3
# 취급액 :  43871000 개수 :  2
# 취급액 :  92354000 개수 :  3
# 취급액 :  59821000 개수 :  3
# 취급액 :  51001000 개수 :  3
# 취급액 :  122803000 개수 :  3
# 취급액 :  121488000 개수 :  3
# 취급액 :  121667000 개수 :  3
# 취급액 :  108388000 개수 :  3
# 취급액 :  29402000 개수 :  3
# 취급액 :  27999000 개수 :  3
# 취급액 :  144509000 개수 :  3
# 취급액 :  122650000 개수 :  3
# 취급액 :  103535000 개수 :  3
# 취급액 :  13550000 개수 :  3
# 취급액 :  41006000 개수 :  3
# 취급액 :  15555000 개수 :  3
# 취급액 :  29673000 개수 :  3
# 취급액 :  48240000 개수 :  3
# 취급액 :  117206000 개수 :  3
# 취급액 :  121682000 개수 :  3
# 취급액 :  55918000 개수 :  3
# 취급액 :  11974000 개수 :  3
# 취급액 :  16342000 개수 :  3
# 취급액 :  45234000 개수 :  3
# 취급액 :  122080000 개수 :  3
# 취급액 :  151665000 개수 :  3
# 취급액 :  170345000 개수 :  3
# 취급액 :  115216000 개수 :  2
# 취급액 :  5422000 개수 :  3
# 취급액 :  29626000 개수 :  3
# 취급액 :  5423000 개수 :  3
# 취급액 :  40280000 개수 :  3
# 취급액 :  9911000 개수 :  3
# 취급액 :  19694000 개수 :  3
# 취급액 :  61592000 개수 :  3
# 취급액 :  77314000 개수 :  3
# 취급액 :  72597000 개수 :  3
# 취급액 :  71254000 개수 :  2
# 취급액 :  117153000 개수 :  3
# 취급액 :  31614000 개수 :  3
# 취급액 :  61394000 개수 :  3
# 취급액 :  28150000 개수 :  3
# 취급액 :  21882000 개수 :  3
# 취급액 :  12540000 개수 :  3
# 취급액 :  150000 개수 :  3
# 취급액 :  33489000 개수 :  3
# 취급액 :  32825000 개수 :  3
# 취급액 :  100292000 개수 :  3
# 취급액 :  187722000 개수 :  3
# 취급액 :  153882000 개수 :  3
# 취급액 :  40359000 개수 :  3
# 취급액 :  48524000 개수 :  3
# 취급액 :  90986000 개수 :  3
# 취급액 :  111534000 개수 :  3
# 취급액 :  58683000 개수 :  2
# 취급액 :  60308000 개수 :  3
# 취급액 :  92213000 개수 :  3
# 취급액 :  30203000 개수 :  3
# 취급액 :  50172000 개수 :  3
# 취급액 :  11301000 개수 :  3
# 취급액 :  78189000 개수 :  3
# 취급액 :  58617000 개수 :  3
# 취급액 :  80838000 개수 :  3
# 취급액 :  103036000 개수 :  3
# 취급액 :  38100000 개수 :  3
# 취급액 :  43208000 개수 :  2
# 취급액 :  151806000 개수 :  3
# 취급액 :  136256000 개수 :  3
# 취급액 :  45474000 개수 :  3
# 취급액 :  27150000 개수 :  3
# 취급액 :  23080000 개수 :  3
# 취급액 :  93141000 개수 :  3
# 취급액 :  106378000 개수 :  3
# 취급액 :  55183000 개수 :  3
# 취급액 :  41548000 개수 :  3
# 취급액 :  34760000 개수 :  3
# 취급액 :  123242000 개수 :  3
# 취급액 :  42122000 개수 :  3
# 취급액 :  86002000 개수 :  3
# 취급액 :  159931000 개수 :  3
# 취급액 :  127187000 개수 :  3
# 취급액 :  120590000 개수 :  3
# 취급액 :  88858000 개수 :  3
# 취급액 :  209675000 개수 :  3
# 취급액 :  20999000 개수 :  3
# 취급액 :  10429000 개수 :  3
# 취급액 :  14598000 개수 :  3
# 취급액 :  22065000 개수 :  3
# 취급액 :  64322000 개수 :  3
# 취급액 :  19714000 개수 :  3
# 취급액 :  139820000 개수 :  3
# 취급액 :  181784000 개수 :  3
# 취급액 :  27559000 개수 :  3
# 취급액 :  62174000 개수 :  3
# 취급액 :  39937000 개수 :  3
# 취급액 :  45985000 개수 :  3
# 취급액 :  79283000 개수 :  2
# 취급액 :  153048000 개수 :  3
# 취급액 :  36761000 개수 :  3
# 취급액 :  17662000 개수 :  3
# 취급액 :  7174000 개수 :  3
# 취급액 :  21881000 개수 :  3
# 취급액 :  4272000 개수 :  3
# 취급액 :  6711000 개수 :  3
# 취급액 :  83569000 개수 :  3
# 취급액 :  15543000 개수 :  3
# 취급액 :  26634000 개수 :  3
# 취급액 :  150009000 개수 :  3
# 취급액 :  59094000 개수 :  3
# 취급액 :  69252000 개수 :  3
# 취급액 :  164073000 개수 :  2
# 취급액 :  24143000 개수 :  3
# 취급액 :  17175000 개수 :  3
# 취급액 :  77571000 개수 :  3
# 취급액 :  120520000 개수 :  3
# 취급액 :  81493000 개수 :  3
# 취급액 :  24539000 개수 :  3
# 취급액 :  19839000 개수 :  3
# 취급액 :  71107000 개수 :  3
# 취급액 :  160085000 개수 :  3
# 취급액 :  108450000 개수 :  3
# 취급액 :  188550000 개수 :  3
# 취급액 :  198506000 개수 :  3
# 취급액 :  39341000 개수 :  2
# 취급액 :  14041000 개수 :  3
# 취급액 :  46454000 개수 :  3
# 취급액 :  150000 개수 :  3
# 취급액 :  67054000 개수 :  3
# 취급액 :  67768000 개수 :  3
# 취급액 :  22041000 개수 :  3
# 취급액 :  36830000 개수 :  3
# 취급액 :  32757000 개수 :  3
# 취급액 :  93876000 개수 :  3
# 취급액 :  68795000 개수 :  3
# 취급액 :  25280000 개수 :  3
# 취급액 :  34002000 개수 :  3
# 취급액 :  68145000 개수 :  3
# 취급액 :  33670000 개수 :  2
# 취급액 :  32544000 개수 :  2
# 취급액 :  61467000 개수 :  3
# 취급액 :  240589000 개수 :  3
# 취급액 :  82608000 개수 :  3
# 취급액 :  15471000 개수 :  3
# 취급액 :  22765000 개수 :  3
# 취급액 :  16727000 개수 :  3
# 취급액 :  48229000 개수 :  3
# 취급액 :  8560000 개수 :  3
# 취급액 :  41998000 개수 :  3
# 취급액 :  41797000 개수 :  3
# 취급액 :  57026000 개수 :  3
# 취급액 :  60143000 개수 :  3
# 취급액 :  104365000 개수 :  3
# 취급액 :  45651000 개수 :  3
# 취급액 :  15667000 개수 :  3
# 취급액 :  95482000 개수 :  3
# 취급액 :  28230000 개수 :  3
# 취급액 :  156149000 개수 :  3
# 취급액 :  131175000 개수 :  3
# 취급액 :  37329000 개수 :  3
# 취급액 :  4586000 개수 :  3
# 취급액 :  12109000 개수 :  3
# 취급액 :  32655000 개수 :  3
# 취급액 :  116599000 개수 :  3
# 취급액 :  78023000 개수 :  3
# 취급액 :  101023000 개수 :  3
# 취급액 :  33947000 개수 :  2
# 취급액 :  110700000 개수 :  3
# 취급액 :  101063000 개수 :  3
# 취급액 :  80677000 개수 :  3
# 취급액 :  89286000 개수 :  2
# 취급액 :  39348000 개수 :  3
# 취급액 :  54956000 개수 :  3
# 취급액 :  129957000 개수 :  3
# 취급액 :  150582000 개수 :  3
# 취급액 :  2760000 개수 :  3
# 취급액 :  13272000 개수 :  3
# 취급액 :  14150000 개수 :  3
# 취급액 :  60649000 개수 :  3
# 취급액 :  6268000 개수 :  3
# 취급액 :  24321000 개수 :  3
# 취급액 :  8394000 개수 :  3
# 취급액 :  13272000 개수 :  3
# 취급액 :  74280000 개수 :  3
# 취급액 :  25381000 개수 :  3
# 취급액 :  107918000 개수 :  3
# 취급액 :  45334000 개수 :  3
# 취급액 :  74554000 개수 :  3
# 취급액 :  106034000 개수 :  3
# 취급액 :  100291000 개수 :  3
# 취급액 :  97849000 개수 :  3
# 취급액 :  155822000 개수 :  3
# 취급액 :  131126000 개수 :  3
# 취급액 :  99082000 개수 :  3
# 취급액 :  98592000 개수 :  3
# 취급액 :  150329000 개수 :  3
# 취급액 :  19830000 개수 :  3
# 취급액 :  96639000 개수 :  3
# 취급액 :  63747000 개수 :  3
# 취급액 :  72377000 개수 :  3
# 취급액 :  147329000 개수 :  3
# 취급액 :  39989000 개수 :  3
# 취급액 :  46007000 개수 :  2
# 취급액 :  43424000 개수 :  3
# 취급액 :  122713000 개수 :  3
# 취급액 :  7302000 개수 :  3
# 취급액 :  3591000 개수 :  3
# 취급액 :  19185000 개수 :  3
# 취급액 :  3484000 개수 :  3
# 취급액 :  6549000 개수 :  3
# 취급액 :  6010000 개수 :  3
# 취급액 :  124170000 개수 :  3
# 취급액 :  64947000 개수 :  3
# 취급액 :  12196000 개수 :  3
# 취급액 :  24753000 개수 :  3
# 취급액 :  30943000 개수 :  3
# 취급액 :  8478000 개수 :  3
# 취급액 :  67209000 개수 :  3
# 취급액 :  17243000 개수 :  3
# 취급액 :  95810000 개수 :  2
# 취급액 :  17120000 개수 :  3
# 취급액 :  46299000 개수 :  3
# 취급액 :  20276000 개수 :  3
# 취급액 :  33256000 개수 :  3
# 취급액 :  49260000 개수 :  3
# 취급액 :  58516000 개수 :  3
# 취급액 :  65983000 개수 :  3
# 취급액 :  17141000 개수 :  3
# 취급액 :  17023000 개수 :  3
# 취급액 :  45227000 개수 :  3
# 취급액 :  126854000 개수 :  3
# 취급액 :  141309000 개수 :  3
# 취급액 :  104600000 개수 :  3
# 취급액 :  87477000 개수 :  2
# 취급액 :  2030000 개수 :  2
# 취급액 :  7709000 개수 :  2
# 취급액 :  22880000 개수 :  2
# 취급액 :  4243000 개수 :  2
# 취급액 :  6001000 개수 :  2
# 취급액 :  24616000 개수 :  2
# 취급액 :  99030000 개수 :  3
# 취급액 :  261345000 개수 :  3
# 취급액 :  62294000 개수 :  3
# 취급액 :  83130000 개수 :  3
# 취급액 :  9326000 개수 :  3
# 취급액 :  63295000 개수 :  3
# 취급액 :  19830000 개수 :  3
# 취급액 :  79887000 개수 :  3
# 취급액 :  40820000 개수 :  3
# 취급액 :  37700000 개수 :  3
# 취급액 :  43636000 개수 :  3
# 취급액 :  83965000 개수 :  3
# 취급액 :  41937000 개수 :  3
# 취급액 :  130343000 개수 :  3
# 취급액 :  83515000 개수 :  3
# 취급액 :  77532000 개수 :  3
# 취급액 :  48593000 개수 :  2
# 취급액 :  146817000 개수 :  3
# 취급액 :  58263000 개수 :  3
# 취급액 :  8283000 개수 :  3
# 취급액 :  13518000 개수 :  3
# 취급액 :  48942000 개수 :  3
# 취급액 :  120474000 개수 :  3
# 취급액 :  110368000 개수 :  3
# 취급액 :  363002000 개수 :  6
# ------------------------------------------------ (1, 24, 200039)
# 취급액 :  20460000 개수 :  3
# 취급액 :  96332000 개수 :  3
# 취급액 :  98887000 개수 :  3
# 취급액 :  5829000 개수 :  3
# 취급액 :  49946000 개수 :  3
# 취급액 :  20970000 개수 :  3
# 취급액 :  2764000 개수 :  3
# 취급액 :  17057000 개수 :  3
# 취급액 :  4210000 개수 :  3
# 취급액 :  15336000 개수 :  3
# 취급액 :  21945000 개수 :  3
# 취급액 :  52291000 개수 :  3
# 취급액 :  54119000 개수 :  3
# 취급액 :  159141000 개수 :  3
# 취급액 :  128674000 개수 :  3
# 취급액 :  100640000 개수 :  3
# 취급액 :  41932000 개수 :  3
# 취급액 :  35151000 개수 :  3
# 취급액 :  21150000 개수 :  3
# 취급액 :  38809000 개수 :  3
# 취급액 :  24882000 개수 :  3
# 취급액 :  19857000 개수 :  3
# 취급액 :  119556000 개수 :  3
# 취급액 :  99334000 개수 :  3
# 취급액 :  32056000 개수 :  3
# 취급액 :  127404000 개수 :  3
# 취급액 :  121867000 개수 :  2
# 취급액 :  85665000 개수 :  3
# 취급액 :  159899000 개수 :  3
# 취급액 :  87062000 개수 :  2
# 취급액 :  4786000 개수 :  3
# 취급액 :  56274000 개수 :  3
# 취급액 :  100915000 개수 :  3
# 취급액 :  27933000 개수 :  3
# 취급액 :  46454000 개수 :  3
# 취급액 :  150000 개수 :  3
# 취급액 :  22041000 개수 :  3
# 취급액 :  73509000 개수 :  3
# 취급액 :  150000 개수 :  3
# 취급액 :  83232000 개수 :  3
# 취급액 :  93350000 개수 :  2
# 취급액 :  104161000 개수 :  3
# 취급액 :  113923000 개수 :  3
# 취급액 :  71306000 개수 :  3
# 취급액 :  9354000 개수 :  3
# 취급액 :  55080000 개수 :  3
# 취급액 :  14167000 개수 :  3
# 취급액 :  103187000 개수 :  3
# 취급액 :  33805000 개수 :  2
# 취급액 :  11507000 개수 :  2
# 취급액 :  146378000 개수 :  3
# 취급액 :  3552000 개수 :  3
# 취급액 :  8008000 개수 :  3
# 취급액 :  109652000 개수 :  3
# 취급액 :  63705000 개수 :  3
# 취급액 :  11221000 개수 :  3
# 취급액 :  142178000 개수 :  3
# 취급액 :  57787000 개수 :  3
# 취급액 :  101240000 개수 :  3
# 취급액 :  164027000 개수 :  3
# 취급액 :  195193000 개수 :  3
# 취급액 :  41230000 개수 :  3
# 취급액 :  62711000 개수 :  3
# 취급액 :  168254000 개수 :  3
# 취급액 :  156087000 개수 :  3
# 취급액 :  68371000 개수 :  3
# 취급액 :  75204000 개수 :  3
# 취급액 :  87324000 개수 :  3
# 취급액 :  104718000 개수 :  3
# 취급액 :  106007000 개수 :  2
# 취급액 :  118967000 개수 :  3
# 취급액 :  50989000 개수 :  3
# 취급액 :  22145000 개수 :  3
# 취급액 :  16528000 개수 :  3
# 취급액 :  244328000 개수 :  3
# 취급액 :  115797000 개수 :  3
# 취급액 :  58596000 개수 :  3
# 취급액 :  11678000 개수 :  3
# 취급액 :  23956000 개수 :  3
# 취급액 :  191343000 개수 :  3
# 취급액 :  176534000 개수 :  2
# 취급액 :  92117000 개수 :  3
# 취급액 :  115565000 개수 :  3
# 취급액 :  235816000 개수 :  3
# 취급액 :  201642000 개수 :  3
# 취급액 :  204704000 개수 :  3
# 취급액 :  146271000 개수 :  3
# 취급액 :  183174000 개수 :  3
# 취급액 :  24465000 개수 :  3
# 취급액 :  31011000 개수 :  3
# 취급액 :  7374000 개수 :  3
# 취급액 :  73312000 개수 :  3
# 취급액 :  6404000 개수 :  3
# 취급액 :  50600000 개수 :  3
# 취급액 :  13192000 개수 :  3
# 취급액 :  92461000 개수 :  3
# 취급액 :  15028000 개수 :  3
# 취급액 :  7942000 개수 :  3
# 취급액 :  18936000 개수 :  3
# 취급액 :  5022000 개수 :  3
# 취급액 :  40015000 개수 :  3
# 취급액 :  205727000 개수 :  3
# 취급액 :  178766000 개수 :  3
# 취급액 :  38017000 개수 :  3
# 취급액 :  96884000 개수 :  3
# 취급액 :  25461000 개수 :  3
# 취급액 :  139069000 개수 :  3
# 취급액 :  46108000 개수 :  3
# 취급액 :  4047000 개수 :  3
# 취급액 :  158452000 개수 :  3
# 취급액 :  44468000 개수 :  3
# 취급액 :  10210000 개수 :  3
# 취급액 :  73872000 개수 :  3
# 취급액 :  24074000 개수 :  3
# 취급액 :  129404000 개수 :  2
# 취급액 :  164309000 개수 :  3
# 취급액 :  79196000 개수 :  3
# 취급액 :  112893000 개수 :  3
# 취급액 :  237747000 개수 :  3
# 취급액 :  34051000 개수 :  3
# 취급액 :  60014000 개수 :  3
# 취급액 :  150142000 개수 :  3
# 취급액 :  134814000 개수 :  3
# 취급액 :  129274000 개수 :  3
# 취급액 :  11444000 개수 :  3
# 취급액 :  25560000 개수 :  3
# 취급액 :  42300000 개수 :  3
# 취급액 :  226363000 개수 :  3
# 취급액 :  86812000 개수 :  3
# 취급액 :  124579000 개수 :  3
# 취급액 :  39733000 개수 :  3
# 취급액 :  32684000 개수 :  3
# 취급액 :  108909000 개수 :  3
# 취급액 :  24601000 개수 :  3
# 취급액 :  131277000 개수 :  3
# 취급액 :  69279000 개수 :  3
# 취급액 :  103485000 개수 :  3
# 취급액 :  97101000 개수 :  2
# 취급액 :  43420000 개수 :  3
# 취급액 :  69827000 개수 :  3
# 취급액 :  19363000 개수 :  3
# 취급액 :  21951000 개수 :  3
# 취급액 :  55578000 개수 :  3
# 취급액 :  165278000 개수 :  3
# 취급액 :  91124000 개수 :  3
# 취급액 :  130909000 개수 :  3
# 취급액 :  70268000 개수 :  3
# 취급액 :  122974000 개수 :  3
# 취급액 :  111889000 개수 :  3
# 취급액 :  104594000 개수 :  3
# 취급액 :  106949000 개수 :  3
# 취급액 :  97145000 개수 :  3
# 취급액 :  128860000 개수 :  3
# 취급액 :  97237000 개수 :  3
# 취급액 :  45097000 개수 :  2
# 취급액 :  75674000 개수 :  3
# 취급액 :  32479000 개수 :  3
# 취급액 :  278123000 개수 :  3
# 취급액 :  101264000 개수 :  3
# 취급액 :  106071000 개수 :  3
# 취급액 :  114484000 개수 :  3
# 취급액 :  25006000 개수 :  3
# 취급액 :  143755000 개수 :  3
# 취급액 :  112394000 개수 :  3
# 취급액 :  33235000 개수 :  3
# 취급액 :  10726000 개수 :  3
# 취급액 :  75053000 개수 :  3
# 취급액 :  28630000 개수 :  3
# 취급액 :  88157000 개수 :  2
# 취급액 :  86527000 개수 :  3
# 취급액 :  91605000 개수 :  3
# 취급액 :  100936000 개수 :  3
# 취급액 :  111015000 개수 :  2
# 취급액 :  13273000 개수 :  3
# 취급액 :  90219000 개수 :  3
# 취급액 :  14017000 개수 :  3
# 취급액 :  41290000 개수 :  3
# 취급액 :  150000 개수 :  3
# 취급액 :  55622000 개수 :  3
# 취급액 :  35983000 개수 :  3
# 취급액 :  25168000 개수 :  3
# 취급액 :  59715000 개수 :  3
# 취급액 :  150000 개수 :  3
# 취급액 :  102209000 개수 :  3
# 취급액 :  47091000 개수 :  3
# 취급액 :  62093000 개수 :  3
# 취급액 :  112214000 개수 :  3
# 취급액 :  125570000 개수 :  3
# 취급액 :  87161000 개수 :  3
# 취급액 :  6296000 개수 :  3
# 취급액 :  70110000 개수 :  3
# 취급액 :  18985000 개수 :  3
# 취급액 :  42196000 개수 :  3
# 취급액 :  100048000 개수 :  3
# 취급액 :  27918000 개수 :  3
# 취급액 :  8998000 개수 :  3
# 취급액 :  62838000 개수 :  3
# 취급액 :  16670000 개수 :  3
# 취급액 :  87092000 개수 :  3
# 취급액 :  14771000 개수 :  3
# 취급액 :  20497000 개수 :  3
# 취급액 :  12048000 개수 :  3
# 취급액 :  14416000 개수 :  3
# 취급액 :  44068000 개수 :  3
# 취급액 :  131293000 개수 :  3
# 취급액 :  87632000 개수 :  3
# 취급액 :  48968000 개수 :  3
# 취급액 :  9767000 개수 :  3
# 취급액 :  7189000 개수 :  3
# 취급액 :  29713000 개수 :  3
# 취급액 :  99315000 개수 :  3
# 취급액 :  43084000 개수 :  3
# 취급액 :  37344000 개수 :  3
# 취급액 :  87174000 개수 :  3
# 취급액 :  95060000 개수 :  2
# 취급액 :  74805000 개수 :  3
# 취급액 :  63558000 개수 :  3
# 취급액 :  15464000 개수 :  3
# 취급액 :  18301000 개수 :  3
# 취급액 :  45648000 개수 :  3
# 취급액 :  124916000 개수 :  3
# 취급액 :  32239000 개수 :  3
# 취급액 :  43903000 개수 :  3
# 취급액 :  101078000 개수 :  3
# 취급액 :  111622000 개수 :  3
# 취급액 :  40932000 개수 :  3
# 취급액 :  44614000 개수 :  3
# 취급액 :  43883000 개수 :  3
# 취급액 :  28175000 개수 :  3
# 취급액 :  15108000 개수 :  3
# 취급액 :  33979000 개수 :  3
# 취급액 :  12540000 개수 :  3
# 취급액 :  19833000 개수 :  3
# 취급액 :  64891000 개수 :  3
# 취급액 :  82318000 개수 :  3
# 취급액 :  23375000 개수 :  3
# 취급액 :  57782000 개수 :  3
# 취급액 :  103549000 개수 :  3
# 취급액 :  64274000 개수 :  2
# 취급액 :  102874000 개수 :  3
# 취급액 :  114675000 개수 :  3
# 취급액 :  46338000 개수 :  3
# 취급액 :  60433000 개수 :  3
# 취급액 :  58366000 개수 :  3
# 취급액 :  78265000 개수 :  3
# 취급액 :  94468000 개수 :  3
# 취급액 :  54069000 개수 :  3
# 취급액 :  54726000 개수 :  3
# 취급액 :  60452000 개수 :  3
# 취급액 :  69641000 개수 :  2
# 취급액 :  19512000 개수 :  3
# 취급액 :  42755000 개수 :  3
# 취급액 :  71801000 개수 :  3
# 취급액 :  78635000 개수 :  3
# 취급액 :  33250000 개수 :  3
# 취급액 :  29886000 개수 :  3
# 취급액 :  47203000 개수 :  3
# 취급액 :  76499000 개수 :  3
# 취급액 :  88169000 개수 :  3
# 취급액 :  102722000 개수 :  3
# 취급액 :  17159000 개수 :  3
# 취급액 :  17092000 개수 :  3
# 취급액 :  14857000 개수 :  3
# 취급액 :  16434000 개수 :  3
# 취급액 :  10856000 개수 :  3
# 취급액 :  20808000 개수 :  3
# 취급액 :  83801000 개수 :  3
# 취급액 :  81108000 개수 :  3
# 취급액 :  148158000 개수 :  3
# 취급액 :  87183000 개수 :  2
# 취급액 :  33282000 개수 :  3
# 취급액 :  21998000 개수 :  3
# 취급액 :  150000 개수 :  3
# 취급액 :  17402000 개수 :  3
# 취급액 :  13413000 개수 :  3
# 취급액 :  43975000 개수 :  3
# 취급액 :  20919000 개수 :  3
# 취급액 :  35291000 개수 :  3
# 취급액 :  75338000 개수 :  3
# 취급액 :  64307000 개수 :  3
# 취급액 :  40680000 개수 :  3
# 취급액 :  104776000 개수 :  3
# 취급액 :  148740000 개수 :  3
# 취급액 :  104886000 개수 :  3
# 취급액 :  3237000 개수 :  3
# 취급액 :  76043000 개수 :  3
# 취급액 :  5280000 개수 :  3
# 취급액 :  23602000 개수 :  3
# 취급액 :  18018000 개수 :  3
# 취급액 :  61129000 개수 :  3
# 취급액 :  17405000 개수 :  3
# 취급액 :  25626000 개수 :  3
# 취급액 :  101749000 개수 :  3
# 취급액 :  24927000 개수 :  3
# 취급액 :  114840000 개수 :  3
# 취급액 :  45531000 개수 :  3
# 취급액 :  108656000 개수 :  3
# 취급액 :  35317000 개수 :  3
# 취급액 :  12607000 개수 :  3
# 취급액 :  66531000 개수 :  3
# 취급액 :  27717000 개수 :  3
# 취급액 :  106509000 개수 :  3
# 취급액 :  73836000 개수 :  3
# 취급액 :  107724000 개수 :  2
# 취급액 :  158077000 개수 :  3
# 취급액 :  65811000 개수 :  2
# 취급액 :  14904000 개수 :  3
# 취급액 :  21972000 개수 :  3
# 취급액 :  7835000 개수 :  3
# 취급액 :  75074000 개수 :  3
# 취급액 :  23413000 개수 :  3
# 취급액 :  39066000 개수 :  3
# 취급액 :  13979000 개수 :  3
# 취급액 :  85546000 개수 :  3
# 취급액 :  42399000 개수 :  3
# 취급액 :  108484000 개수 :  3
# 취급액 :  43911000 개수 :  3
# 취급액 :  78801000 개수 :  3
# 취급액 :  122965000 개수 :  6
# ------------------------------------------------ (2, 3, 201704)
# 취급액 :  21766000 개수 :  6
# ------------------------------------------------ (2, 3, 201706)
# 취급액 :  51984000 개수 :  3
# 취급액 :  87827000 개수 :  6
# ------------------------------------------------ (2, 3, 201756)
# 취급액 :  36633000 개수 :  6
# ------------------------------------------------ (2, 3, 201758)
# 취급액 :  63767000 개수 :  3
# 취급액 :  119021000 개수 :  3
# 취급액 :  89644000 개수 :  3
# 취급액 :  25622000 개수 :  3
# 취급액 :  84750000 개수 :  3
# 취급액 :  68291000 개수 :  3
# 취급액 :  109489000 개수 :  3
# 취급액 :  31593000 개수 :  3
# 취급액 :  12114000 개수 :  3
# 취급액 :  65315000 개수 :  3
# 취급액 :  24034000 개수 :  3
# 취급액 :  109956000 개수 :  3
# 취급액 :  41598000 개수 :  3
# 취급액 :  84459000 개수 :  3
# 취급액 :  120071000 개수 :  3
# 취급액 :  58802000 개수 :  2
# 취급액 :  124158000 개수 :  3
# 취급액 :  84232000 개수 :  2
# 취급액 :  64592000 개수 :  3
# 취급액 :  8190000 개수 :  3
# 취급액 :  70258000 개수 :  3
# 취급액 :  52111000 개수 :  3
# 취급액 :  14563000 개수 :  3
# 취급액 :  65491000 개수 :  3
# 취급액 :  87716000 개수 :  3
# 취급액 :  55827000 개수 :  3
# 취급액 :  40280000 개수 :  3
# 취급액 :  54570000 개수 :  3
# 취급액 :  91996000 개수 :  3
# 취급액 :  51582000 개수 :  3
# 취급액 :  88411000 개수 :  3
# 취급액 :  67129000 개수 :  2
# 취급액 :  42154000 개수 :  3
# 취급액 :  30762000 개수 :  3
# 취급액 :  122886000 개수 :  3
# 취급액 :  44541000 개수 :  3
# 취급액 :  11200000 개수 :  3
# 취급액 :  13978000 개수 :  3
# 취급액 :  28774000 개수 :  3
# 취급액 :  64779000 개수 :  3
# 취급액 :  67262000 개수 :  3
# 취급액 :  88762000 개수 :  3
# 취급액 :  116187000 개수 :  3
# 취급액 :  81572000 개수 :  2
# 취급액 :  14929000 개수 :  3
# 취급액 :  43821000 개수 :  3
# 취급액 :  15470000 개수 :  3
# 취급액 :  78209000 개수 :  3
# 취급액 :  30044000 개수 :  3
# 취급액 :  48756000 개수 :  3
# 취급액 :  150000 개수 :  3
# 취급액 :  126742000 개수 :  3
# 취급액 :  82327000 개수 :  3
# 취급액 :  29703000 개수 :  3
# 취급액 :  58151000 개수 :  3
# 취급액 :  37532000 개수 :  3
# 취급액 :  27633000 개수 :  3
# 취급액 :  37370000 개수 :  3
# 취급액 :  35429000 개수 :  3
# 취급액 :  67146000 개수 :  3
# 취급액 :  18026000 개수 :  3
# 취급액 :  17983000 개수 :  3
# 취급액 :  35215000 개수 :  3
# 취급액 :  62795000 개수 :  3
# 취급액 :  25173000 개수 :  3
# 취급액 :  71390000 개수 :  3
# 취급액 :  5821000 개수 :  3
# 취급액 :  64294000 개수 :  3
# 취급액 :  124886000 개수 :  3
# 취급액 :  37950000 개수 :  3
# 취급액 :  9285000 개수 :  3
# 취급액 :  70175000 개수 :  3
# 취급액 :  28847000 개수 :  3
# 취급액 :  32091000 개수 :  3
# 취급액 :  78072000 개수 :  3
# 취급액 :  49674000 개수 :  3
# 취급액 :  15912000 개수 :  3
# 취급액 :  14432000 개수 :  3
# 취급액 :  38413000 개수 :  3
# 취급액 :  130338000 개수 :  3
# 취급액 :  133088000 개수 :  3
# 취급액 :  16230000 개수 :  3
# 취급액 :  65407000 개수 :  3
# 취급액 :  43809000 개수 :  3
# 취급액 :  7676000 개수 :  3
# 취급액 :  95341000 개수 :  3
# 취급액 :  47113000 개수 :  3
# 취급액 :  59529000 개수 :  3
# 취급액 :  72190000 개수 :  3
# 취급액 :  116708000 개수 :  3
# 취급액 :  28742000 개수 :  3
# 취급액 :  169591000 개수 :  3
# 취급액 :  192344000 개수 :  3
# 취급액 :  28910000 개수 :  3
# 취급액 :  14598000 개수 :  3
# 취급액 :  30979000 개수 :  3
# 취급액 :  48202000 개수 :  3
# 취급액 :  16128000 개수 :  3
# 취급액 :  13792000 개수 :  3
# 취급액 :  14625000 개수 :  3
# 취급액 :  33708000 개수 :  3
# 취급액 :  28768000 개수 :  3
# 취급액 :  22352000 개수 :  3
# 취급액 :  114227000 개수 :  3
# 취급액 :  37101000 개수 :  3
# 취급액 :  155943000 개수 :  3
# 취급액 :  32919000 개수 :  3
# 취급액 :  13197000 개수 :  3
# 취급액 :  87189000 개수 :  3
# 취급액 :  25602000 개수 :  3
# 취급액 :  38283000 개수 :  3
# 취급액 :  35755000 개수 :  3
# 취급액 :  120981000 개수 :  3
# 취급액 :  35028000 개수 :  3
# 취급액 :  42703000 개수 :  3
# 취급액 :  44079000 개수 :  3
# 취급액 :  36417000 개수 :  3
# 취급액 :  42484000 개수 :  3
# 취급액 :  79183000 개수 :  3
# 취급액 :  102106000 개수 :  2
# 취급액 :  86849000 개수 :  3
# 취급액 :  13652000 개수 :  3
# 취급액 :  86956000 개수 :  3
# 취급액 :  51765000 개수 :  3
# 취급액 :  136787000 개수 :  3
# 취급액 :  112837000 개수 :  3
# 취급액 :  71421000 개수 :  2
# 취급액 :  124555000 개수 :  3
# 취급액 :  73495000 개수 :  3
# 취급액 :  179656000 개수 :  3
# 취급액 :  148070000 개수 :  3
# 취급액 :  111330000 개수 :  3
# 취급액 :  72308000 개수 :  3
# 취급액 :  79410000 개수 :  3
# 취급액 :  12384000 개수 :  3
# 취급액 :  74671000 개수 :  3
# 취급액 :  94581000 개수 :  3
# 취급액 :  14195000 개수 :  3
# 취급액 :  115891000 개수 :  3
# 취급액 :  24862000 개수 :  3
# 취급액 :  29479000 개수 :  3
# 취급액 :  6488000 개수 :  3
# 취급액 :  4985000 개수 :  3
# 취급액 :  39436000 개수 :  3
# 취급액 :  134841000 개수 :  3
# 취급액 :  29782000 개수 :  3
# 취급액 :  11531000 개수 :  3
# 취급액 :  67146000 개수 :  3
# 취급액 :  22461000 개수 :  3
# 취급액 :  93106000 개수 :  3
# 취급액 :  19881000 개수 :  3
# 취급액 :  2122000 개수 :  3
# 취급액 :  136926000 개수 :  3
# 취급액 :  129030000 개수 :  3
# 취급액 :  90421000 개수 :  3
# 취급액 :  101618000 개수 :  3
# 취급액 :  55385000 개수 :  3
# 취급액 :  54072000 개수 :  3
# 취급액 :  56326000 개수 :  3
# 취급액 :  107478000 개수 :  3
# 취급액 :  78056000 개수 :  3
# 취급액 :  115623000 개수 :  3
# 취급액 :  68382000 개수 :  2
# 취급액 :  44413000 개수 :  3
# 취급액 :  143260000 개수 :  3
# 취급액 :  63501000 개수 :  3
# 취급액 :  53107000 개수 :  3
# 취급액 :  7857000 개수 :  3
# 취급액 :  48031000 개수 :  3
# 취급액 :  22869000 개수 :  3
# 취급액 :  7401000 개수 :  3
# 취급액 :  153643000 개수 :  3
# 취급액 :  61467000 개수 :  3
# 취급액 :  17617000 개수 :  3
# 취급액 :  132756000 개수 :  3
# 취급액 :  51952000 개수 :  3
# 취급액 :  65271000 개수 :  3
# 취급액 :  46589000 개수 :  3
# 취급액 :  87628000 개수 :  3
# 취급액 :  5001000 개수 :  3
# 취급액 :  29741000 개수 :  3
# 취급액 :  51274000 개수 :  3
# 취급액 :  11407000 개수 :  3
# 취급액 :  17299000 개수 :  3
# 취급액 :  3230000 개수 :  3
# 취급액 :  14445000 개수 :  3
# 취급액 :  36905000 개수 :  3
# 취급액 :  126533000 개수 :  3
# 취급액 :  73988000 개수 :  2
# 취급액 :  186330000 개수 :  3
# 취급액 :  11177000 개수 :  3
# 취급액 :  49219000 개수 :  3
# 취급액 :  150000 개수 :  3
# 취급액 :  23361000 개수 :  3
# 취급액 :  77904000 개수 :  3
# 취급액 :  7064000 개수 :  3
# 취급액 :  112173000 개수 :  2
# 취급액 :  92834000 개수 :  2
# 취급액 :  145981000 개수 :  3
# 취급액 :  113181000 개수 :  3
# 취급액 :  17913000 개수 :  3
# 취급액 :  73890000 개수 :  3
# 취급액 :  19438000 개수 :  3
# 취급액 :  39241000 개수 :  3
# 취급액 :  47814000 개수 :  3
# 취급액 :  23594000 개수 :  3
# 취급액 :  5535000 개수 :  3
# 취급액 :  9992000 개수 :  3
# 취급액 :  94293000 개수 :  3
# 취급액 :  23022000 개수 :  3
# 취급액 :  54070000 개수 :  3
# 취급액 :  112612000 개수 :  3
# 취급액 :  169868000 개수 :  3
# 취급액 :  38847000 개수 :  3
# 취급액 :  13810000 개수 :  3
# 취급액 :  86290000 개수 :  3
# 취급액 :  35166000 개수 :  3
# 취급액 :  106011000 개수 :  3
# 취급액 :  87673000 개수 :  3
# 취급액 :  131599000 개수 :  3
# 취급액 :  89494000 개수 :  3
# 취급액 :  36580000 개수 :  3
# 취급액 :  107141000 개수 :  3
# 취급액 :  195085000 개수 :  3
# 취급액 :  165795000 개수 :  3
# 취급액 :  84576000 개수 :  3
# 취급액 :  95439000 개수 :  3
# 취급액 :  95017000 개수 :  3
# 취급액 :  133895000 개수 :  3
# 취급액 :  118739000 개수 :  3
# 취급액 :  37700000 개수 :  2
# 취급액 :  12457000 개수 :  3
# 취급액 :  21791000 개수 :  3
# 취급액 :  90886000 개수 :  3
# 취급액 :  247950000 개수 :  3
# 취급액 :  128048000 개수 :  3
# 취급액 :  31295000 개수 :  3
# 취급액 :  54826000 개수 :  3
# 취급액 :  71338000 개수 :  3
# 취급액 :  12385000 개수 :  3
# 취급액 :  37160000 개수 :  3
# 취급액 :  58746000 개수 :  3
# 취급액 :  52647000 개수 :  3
# 취급액 :  16971000 개수 :  3
# 취급액 :  77150000 개수 :  3
# 취급액 :  35417000 개수 :  3
# 취급액 :  48671000 개수 :  3
# 취급액 :  119956000 개수 :  3
# 취급액 :  78366000 개수 :  3
# 취급액 :  163725000 개수 :  3
# 취급액 :  39626000 개수 :  3
# 취급액 :  51994000 개수 :  3
# 취급액 :  44347000 개수 :  3
# 취급액 :  31936000 개수 :  3
# 취급액 :  73212000 개수 :  3
# 취급액 :  21906000 개수 :  3
# 취급액 :  27999000 개수 :  3
# 취급액 :  65398000 개수 :  3
# 취급액 :  85261000 개수 :  3
# 취급액 :  80757000 개수 :  2
# 취급액 :  128246000 개수 :  3
# 취급액 :  97292000 개수 :  2
# 취급액 :  63794000 개수 :  3
# 취급액 :  93295000 개수 :  3
# 취급액 :  53795000 개수 :  3
# 취급액 :  81273000 개수 :  2
# 취급액 :  36157000 개수 :  3
# 취급액 :  70401000 개수 :  3
# 취급액 :  60969000 개수 :  3
# 취급액 :  60572000 개수 :  3
# 취급액 :  37370000 개수 :  3
# 취급액 :  70501000 개수 :  3
# 취급액 :  28015000 개수 :  3
# 취급액 :  6443000 개수 :  3
# 취급액 :  12142000 개수 :  3
# 취급액 :  116710000 개수 :  3
# 취급액 :  99280000 개수 :  3
# 취급액 :  119939000 개수 :  3
# 취급액 :  139169000 개수 :  3
# 취급액 :  49498000 개수 :  3
# 취급액 :  101712000 개수 :  3
# 취급액 :  75596000 개수 :  2
# 취급액 :  122731000 개수 :  3
# 취급액 :  8746000 개수 :  3
# 취급액 :  75162000 개수 :  3
# 취급액 :  22280000 개수 :  3
# 취급액 :  60117000 개수 :  3
# 취급액 :  30815000 개수 :  3
# 취급액 :  60590000 개수 :  3
# 취급액 :  36676000 개수 :  3
# 취급액 :  77905000 개수 :  3
# 취급액 :  34721000 개수 :  3
# 취급액 :  69713000 개수 :  3
# 취급액 :  88559000 개수 :  3
# 취급액 :  26524000 개수 :  3
# 취급액 :  142007000 개수 :  3
# 취급액 :  131606000 개수 :  3
# 취급액 :  50874000 개수 :  2
# 취급액 :  168595000 개수 :  3
# 취급액 :  20076000 개수 :  3
# 취급액 :  12411000 개수 :  3
# 취급액 :  28231000 개수 :  3
# 취급액 :  33857000 개수 :  3
# 취급액 :  22618000 개수 :  3
# 취급액 :  47362000 개수 :  3
# 취급액 :  40566000 개수 :  3
# 취급액 :  71222000 개수 :  3
# 취급액 :  52452000 개수 :  3
# 취급액 :  28526000 개수 :  3
# 취급액 :  7565000 개수 :  3
# 취급액 :  54068000 개수 :  3
# 취급액 :  21912000 개수 :  3
# 취급액 :  56179000 개수 :  3
# 취급액 :  50863000 개수 :  3
# 취급액 :  112783000 개수 :  3
# 취급액 :  42134000 개수 :  3
# 취급액 :  56854000 개수 :  3
# 취급액 :  111579000 개수 :  3
# 취급액 :  50720000 개수 :  2
# 취급액 :  120348000 개수 :  2
# 취급액 :  14904000 개수 :  3
# 취급액 :  27447000 개수 :  3
# 취급액 :  30815000 개수 :  3
# 취급액 :  94823000 개수 :  3
# 취급액 :  16755000 개수 :  3
# 취급액 :  39066000 개수 :  3
# 취급액 :  20893000 개수 :  3
# 취급액 :  144562000 개수 :  3
# 취급액 :  29549000 개수 :  3
# 취급액 :  77625000 개수 :  3
# 취급액 :  46380000 개수 :  3
# 취급액 :  161632000 개수 :  3
# 취급액 :  102765000 개수 :  3
# 취급액 :  113784000 개수 :  3
# 취급액 :  34535000 개수 :  3
# 취급액 :  8974000 개수 :  3
# 취급액 :  8014000 개수 :  3
# 취급액 :  130415000 개수 :  3
# 취급액 :  72938000 개수 :  3
# 취급액 :  113598000 개수 :  3
# 취급액 :  93852000 개수 :  3
# 취급액 :  35313000 개수 :  3
# 취급액 :  41071000 개수 :  3
# 취급액 :  19233000 개수 :  3
# 취급액 :  30355000 개수 :  3
# 취급액 :  23824000 개수 :  3
# 취급액 :  21887000 개수 :  3
# 취급액 :  52848000 개수 :  3
# 취급액 :  19654000 개수 :  3
# 취급액 :  16575000 개수 :  3
# 취급액 :  40657000 개수 :  3
# 취급액 :  77625000 개수 :  3
# 취급액 :  78553000 개수 :  2
# 취급액 :  123435000 개수 :  3
# 취급액 :  71776000 개수 :  3
# 취급액 :  106984000 개수 :  3
# 취급액 :  47043000 개수 :  3
# 취급액 :  58144000 개수 :  3
# 취급액 :  40513000 개수 :  3
# 취급액 :  102331000 개수 :  3
# 취급액 :  80430000 개수 :  3
# 취급액 :  8454000 개수 :  3
# 취급액 :  20065000 개수 :  3
# 취급액 :  9978000 개수 :  3
# 취급액 :  21601000 개수 :  3
# 취급액 :  11381000 개수 :  3
# 취급액 :  42251000 개수 :  3
# 취급액 :  102652000 개수 :  3
# 취급액 :  160681000 개수 :  3
# 취급액 :  77396000 개수 :  3
# 취급액 :  18856000 개수 :  3
# 취급액 :  5189000 개수 :  3
# 취급액 :  6785000 개수 :  3
# 취급액 :  39621000 개수 :  3
# 취급액 :  11544000 개수 :  3
# 취급액 :  59871000 개수 :  3
# 취급액 :  25173000 개수 :  3
# 취급액 :  120737000 개수 :  2
# 취급액 :  141123000 개수 :  3
# 취급액 :  20617000 개수 :  3
# 취급액 :  21753000 개수 :  3
# 취급액 :  14894000 개수 :  3
# 취급액 :  13782000 개수 :  3
# 취급액 :  51261000 개수 :  3
# 취급액 :  94342000 개수 :  3
# 취급액 :  133317000 개수 :  3
# 취급액 :  65846000 개수 :  2
# 취급액 :  135422000 개수 :  3
# 취급액 :  94014000 개수 :  2
# 취급액 :  22281000 개수 :  3
# 취급액 :  65644000 개수 :  3
# 취급액 :  7810000 개수 :  3
# 취급액 :  20097000 개수 :  3
# 취급액 :  58446000 개수 :  3
# 취급액 :  20919000 개수 :  3
# 취급액 :  66244000 개수 :  3
# 취급액 :  41884000 개수 :  3
# 취급액 :  73676000 개수 :  3
# 취급액 :  105092000 개수 :  3
# 취급액 :  22578000 개수 :  3
# 취급액 :  48951000 개수 :  3
# 취급액 :  98949000 개수 :  3
# 취급액 :  189390000 개수 :  3
# 취급액 :  140978000 개수 :  3
# 취급액 :  119128000 개수 :  3
# 취급액 :  168308000 개수 :  3
# 취급액 :  170258000 개수 :  6
# ------------------------------------------------ (2, 15, 201704)
# 취급액 :  15369000 개수 :  6
# ------------------------------------------------ (2, 15, 201706)
# 취급액 :  45834000 개수 :  6
# ------------------------------------------------ (2, 15, 201756)
# 취급액 :  25531000 개수 :  6
# ------------------------------------------------ (2, 15, 201758)
# 취급액 :  42536000 개수 :  3
# 취급액 :  6115000 개수 :  3
# 취급액 :  102146000 개수 :  3
# 취급액 :  27151000 개수 :  3
# 취급액 :  37125000 개수 :  3
# 취급액 :  2358000 개수 :  3
# 취급액 :  111199000 개수 :  3
# 취급액 :  80809000 개수 :  3
# 취급액 :  82687000 개수 :  3
# 취급액 :  14404000 개수 :  3
# 취급액 :  30134000 개수 :  3
# 취급액 :  69124000 개수 :  3
# 취급액 :  137769000 개수 :  3
# 취급액 :  14853000 개수 :  3
# 취급액 :  65566000 개수 :  3
# 취급액 :  7810000 개수 :  3
# 취급액 :  63305000 개수 :  3
# 취급액 :  73150000 개수 :  3
# 취급액 :  7064000 개수 :  3
# 취급액 :  62770000 개수 :  3
# 취급액 :  29035000 개수 :  3
# 취급액 :  53097000 개수 :  3
# 취급액 :  115615000 개수 :  3
# 취급액 :  125060000 개수 :  3
# 취급액 :  57714000 개수 :  2
# 취급액 :  135224000 개수 :  3
# 취급액 :  221116000 개수 :  3
# 취급액 :  152350000 개수 :  3
# 취급액 :  208355000 개수 :  3
# 취급액 :  130440000 개수 :  3
# 취급액 :  150920000 개수 :  3
# 취급액 :  132376000 개수 :  3
# 취급액 :  6267000 개수 :  3
# 취급액 :  29748000 개수 :  3
# 취급액 :  53037000 개수 :  3
# 취급액 :  36286000 개수 :  3
# 취급액 :  83892000 개수 :  3
# 취급액 :  2758000 개수 :  3
# 취급액 :  44173000 개수 :  3
# 취급액 :  10225000 개수 :  3
# 취급액 :  95916000 개수 :  2
# 취급액 :  111117000 개수 :  3
# 취급액 :  120924000 개수 :  3
# 취급액 :  72504000 개수 :  3
# 취급액 :  49598000 개수 :  3
# 취급액 :  27914000 개수 :  3
# 취급액 :  142200000 개수 :  3
# 취급액 :  83058000 개수 :  3
# 취급액 :  96692000 개수 :  3
# 취급액 :  92085000 개수 :  3
# 취급액 :  54073000 개수 :  3
# 취급액 :  27434000 개수 :  3
# 취급액 :  41337000 개수 :  3
# 취급액 :  114249000 개수 :  3
# 취급액 :  11545000 개수 :  3
# 취급액 :  19532000 개수 :  3
# 취급액 :  125846000 개수 :  3
# 취급액 :  106735000 개수 :  3
# 취급액 :  52060000 개수 :  3
# 취급액 :  83205000 개수 :  3
# 취급액 :  6296000 개수 :  3
# 취급액 :  44572000 개수 :  3
# 취급액 :  80043000 개수 :  3
# 취급액 :  52817000 개수 :  3
# 취급액 :  22297000 개수 :  3
# 취급액 :  70407000 개수 :  3
# 취급액 :  5251000 개수 :  3
# 취급액 :  100048000 개수 :  3
# 취급액 :  23810000 개수 :  3
# 취급액 :  44209000 개수 :  3
# 취급액 :  130678000 개수 :  3
# 취급액 :  12285000 개수 :  3
# 취급액 :  13543000 개수 :  3
# 취급액 :  134883000 개수 :  3
# 취급액 :  24340000 개수 :  3
# 취급액 :  32284000 개수 :  3
# 취급액 :  31798000 개수 :  3
# 취급액 :  25603000 개수 :  3
# 취급액 :  133683000 개수 :  3
# 취급액 :  123154000 개수 :  3
# 취급액 :  180302000 개수 :  3
# 취급액 :  114620000 개수 :  3
# 취급액 :  36620000 개수 :  3
# 취급액 :  55741000 개수 :  3
# 취급액 :  71230000 개수 :  3
# 취급액 :  1123000 개수 :  2
# 취급액 :  6058000 개수 :  2
# 취급액 :  31094000 개수 :  2
# 취급액 :  3285000 개수 :  2
# 취급액 :  4907000 개수 :  2
# 취급액 :  26321000 개수 :  2
# 취급액 :  57848000 개수 :  3
# 취급액 :  83922000 개수 :  3
# 취급액 :  75430000 개수 :  3
# 취급액 :  7001000 개수 :  3
# 취급액 :  19888000 개수 :  3
# 취급액 :  61128000 개수 :  3
# 취급액 :  80884000 개수 :  3
# 취급액 :  58321000 개수 :  3
# 취급액 :  121837000 개수 :  3
# 취급액 :  77121000 개수 :  3
# 취급액 :  10111000 개수 :  3
# 취급액 :  3215000 개수 :  3
# 취급액 :  15602000 개수 :  3
# 취급액 :  21598000 개수 :  3
# 취급액 :  21204000 개수 :  3
# 취급액 :  44799000 개수 :  3
# 취급액 :  90465000 개수 :  3
# 취급액 :  24675000 개수 :  3
# 취급액 :  74585000 개수 :  3
# 취급액 :  5756000 개수 :  3
# 취급액 :  54282000 개수 :  3
# 취급액 :  17872000 개수 :  3
# 취급액 :  14389000 개수 :  3
# 취급액 :  85530000 개수 :  3
# 취급액 :  86447000 개수 :  3
# 취급액 :  43407000 개수 :  3
# 취급액 :  11408000 개수 :  3
# 취급액 :  16575000 개수 :  3
# 취급액 :  30153000 개수 :  3
# 취급액 :  152263000 개수 :  3
# 취급액 :  69452000 개수 :  2
# 취급액 :  119825000 개수 :  3
# 취급액 :  100889000 개수 :  3
# 취급액 :  62182000 개수 :  2
# 취급액 :  121478000 개수 :  3
# 취급액 :  7501000 개수 :  3
# 취급액 :  65541000 개수 :  3
# 취급액 :  23155000 개수 :  3
# 취급액 :  74975000 개수 :  3
# 취급액 :  23387000 개수 :  3
# 취급액 :  53588000 개수 :  3
# 취급액 :  7064000 개수 :  3
# 취급액 :  83895000 개수 :  3
# 취급액 :  62778000 개수 :  3
# 취급액 :  67569000 개수 :  3
# 취급액 :  82516000 개수 :  3
# 취급액 :  55918000 개수 :  3
# 취급액 :  37147000 개수 :  2
# 취급액 :  49088000 개수 :  2
# 취급액 :  97507000 개수 :  3
# 취급액 :  164378000 개수 :  3
# 취급액 :  115015000 개수 :  3
# 취급액 :  2019000 개수 :  3
# 취급액 :  30926000 개수 :  3
# 취급액 :  8734000 개수 :  3
# 취급액 :  59970000 개수 :  3
# 취급액 :  112715000 개수 :  3
# 취급액 :  143878000 개수 :  3
# 취급액 :  24960000 개수 :  3
# 취급액 :  25603000 개수 :  3
# 취급액 :  29080000 개수 :  3
# 취급액 :  21954000 개수 :  3
# 취급액 :  48341000 개수 :  3
# 취급액 :  59919000 개수 :  3
# 취급액 :  16643000 개수 :  3
# 취급액 :  15866000 개수 :  3
# 취급액 :  45886000 개수 :  3
# 취급액 :  116531000 개수 :  3
# 취급액 :  70671000 개수 :  2
# 취급액 :  141282000 개수 :  3
# 취급액 :  78793000 개수 :  2
# 취급액 :  105557000 개수 :  3
# 취급액 :  48707000 개수 :  2
# 취급액 :  108626000 개수 :  3
# 취급액 :  64011000 개수 :  3
# 취급액 :  151375000 개수 :  3
# 취급액 :  125216000 개수 :  3
# 취급액 :  16749000 개수 :  3
# 취급액 :  29252000 개수 :  3
# 취급액 :  12783000 개수 :  3
# 취급액 :  20070000 개수 :  3
# 취급액 :  22623000 개수 :  3
# 취급액 :  53733000 개수 :  3
# 취급액 :  166575000 개수 :  3
# 취급액 :  40378000 개수 :  3
# 취급액 :  29046000 개수 :  3
# 취급액 :  7884000 개수 :  3
# 취급액 :  56396000 개수 :  3
# 취급액 :  6268000 개수 :  3
# 취급액 :  26736000 개수 :  3
# 취급액 :  9227000 개수 :  3
# 취급액 :  14625000 개수 :  3
# 취급액 :  46204000 개수 :  3
# 취급액 :  14167000 개수 :  3
# 취급액 :  56631000 개수 :  3
# 취급액 :  2320000 개수 :  3
# 취급액 :  69614000 개수 :  3
# 취급액 :  101687000 개수 :  3
# 취급액 :  33312000 개수 :  3
# 취급액 :  31870000 개수 :  3
# 취급액 :  24153000 개수 :  3
# 취급액 :  2121000 개수 :  3
# 취급액 :  99273000 개수 :  3
# 취급액 :  12373000 개수 :  3
# 취급액 :  75722000 개수 :  3
# 취급액 :  66239000 개수 :  3
# 취급액 :  49900000 개수 :  3
# 취급액 :  75160000 개수 :  3
# 취급액 :  34243000 개수 :  2
# 취급액 :  59763000 개수 :  3
# 취급액 :  105277000 개수 :  3
# 취급액 :  102329000 개수 :  3
# 취급액 :  57737000 개수 :  3
# 취급액 :  127516000 개수 :  3
# 취급액 :  136468000 개수 :  3
# 취급액 :  92009000 개수 :  3
# 취급액 :  56381000 개수 :  3
# 취급액 :  12048000 개수 :  3
# 취급액 :  35583000 개수 :  3
# 취급액 :  27961000 개수 :  3
# 취급액 :  6492000 개수 :  3
# 취급액 :  84948000 개수 :  3
# 취급액 :  24110000 개수 :  3
# 취급액 :  126528000 개수 :  3
# 취급액 :  23515000 개수 :  3
# 취급액 :  18036000 개수 :  3
# 취급액 :  24336000 개수 :  3
# 취급액 :  19277000 개수 :  3
# 취급액 :  47925000 개수 :  3
# 취급액 :  89280000 개수 :  3
# 취급액 :  3391000 개수 :  3
# 취급액 :  24128000 개수 :  3
# 취급액 :  59915000 개수 :  3
# 취급액 :  19672000 개수 :  3
# 취급액 :  13720000 개수 :  3
# 취급액 :  4744000 개수 :  3
# 취급액 :  9037000 개수 :  3
# 취급액 :  33848000 개수 :  3
# 취급액 :  184124000 개수 :  3
# 취급액 :  144984000 개수 :  3
# 취급액 :  136078000 개수 :  3
# 취급액 :  87146000 개수 :  2
# 취급액 :  115464000 개수 :  3
# 취급액 :  99061000 개수 :  3
# 취급액 :  78237000 개수 :  3
# 취급액 :  91449000 개수 :  3
# 취급액 :  64499000 개수 :  3
# 취급액 :  59543000 개수 :  3
# 취급액 :  88388000 개수 :  3
# 취급액 :  61878000 개수 :  3
# 취급액 :  22498000 개수 :  3
# 취급액 :  25829000 개수 :  3
# 취급액 :  73820000 개수 :  3
# 취급액 :  47909000 개수 :  2
# 취급액 :  47219000 개수 :  2
# 취급액 :  74986000 개수 :  3
# 취급액 :  92261000 개수 :  3
# 취급액 :  137679000 개수 :  3
# 취급액 :  56877000 개수 :  3
# 취급액 :  16352000 개수 :  3
# 취급액 :  15930000 개수 :  3
# 취급액 :  37901000 개수 :  3
# 취급액 :  23173000 개수 :  3
# 취급액 :  117402000 개수 :  3
# 취급액 :  124693000 개수 :  3
# 취급액 :  100347000 개수 :  3
# 취급액 :  60697000 개수 :  3
# 취급액 :  19651000 개수 :  3
# 취급액 :  16557000 개수 :  3
# 취급액 :  59408000 개수 :  3
# 취급액 :  129799000 개수 :  3
# 취급액 :  104792000 개수 :  3
# 취급액 :  131231000 개수 :  3
# 취급액 :  11203000 개수 :  3
# 취급액 :  60220000 개수 :  3
# 취급액 :  38500000 개수 :  3
# 취급액 :  68740000 개수 :  3
# 취급액 :  60322000 개수 :  3
# 취급액 :  36650000 개수 :  3
# 취급액 :  63330000 개수 :  3
# 취급액 :  41662000 개수 :  3
# 취급액 :  95308000 개수 :  3
# 취급액 :  78181000 개수 :  3
# 취급액 :  122266000 개수 :  3
# 취급액 :  128003000 개수 :  3
# 취급액 :  123742000 개수 :  2
# 취급액 :  47471000 개수 :  2
# 취급액 :  52642000 개수 :  2
# 취급액 :  141453000 개수 :  3
# 취급액 :  38110000 개수 :  3
# 취급액 :  171966000 개수 :  3
# 취급액 :  109318000 개수 :  3
# 취급액 :  43856000 개수 :  3
# 취급액 :  128575000 개수 :  3
# 취급액 :  111889000 개수 :  3
# 취급액 :  104463000 개수 :  2
# 취급액 :  103373000 개수 :  3
# 취급액 :  84398000 개수 :  3
# 취급액 :  120265000 개수 :  3
# 취급액 :  286122000 개수 :  6
# ------------------------------------------------ (2, 24, 200191)
# 취급액 :  120398000 개수 :  3
# 취급액 :  103172000 개수 :  2
# 취급액 :  72040000 개수 :  3
# 취급액 :  93955000 개수 :  3
# 취급액 :  1529000 개수 :  3
# 취급액 :  38470000 개수 :  3
# 취급액 :  10494000 개수 :  3
# 취급액 :  86501000 개수 :  3
# 취급액 :  84805000 개수 :  3
# 취급액 :  191349000 개수 :  3
# 취급액 :  13430000 개수 :  3
# 취급액 :  13947000 개수 :  3
# 취급액 :  19806000 개수 :  3
# 취급액 :  20062000 개수 :  3
# 취급액 :  31030000 개수 :  3
# 취급액 :  43519000 개수 :  3
# 취급액 :  101358000 개수 :  3
# 취급액 :  101889000 개수 :  3
# 취급액 :  9354000 개수 :  3
# 취급액 :  56082000 개수 :  3
# 취급액 :  22606000 개수 :  3
# 취급액 :  19463000 개수 :  3
# 취급액 :  4250000 개수 :  3
# 취급액 :  4249000 개수 :  3
# 취급액 :  4120000 개수 :  3
# 취급액 :  75084000 개수 :  3
# 취급액 :  24980000 개수 :  3
# 취급액 :  197475000 개수 :  3
# 취급액 :  41579000 개수 :  3
# 취급액 :  111106000 개수 :  3
# 취급액 :  18295000 개수 :  3
# 취급액 :  17654000 개수 :  3
# 취급액 :  32790000 개수 :  3
# 취급액 :  47199000 개수 :  3
# 취급액 :  28381000 개수 :  3
# 취급액 :  28317000 개수 :  3
# 취급액 :  104796000 개수 :  3
# 취급액 :  45727000 개수 :  3
# 취급액 :  11389000 개수 :  3
# 취급액 :  24401000 개수 :  3
# 취급액 :  52641000 개수 :  3
# 취급액 :  31790000 개수 :  3
# 취급액 :  47972000 개수 :  3
# 취급액 :  109367000 개수 :  3
# 취급액 :  94745000 개수 :  3
# 취급액 :  168601000 개수 :  3
# 취급액 :  9756000 개수 :  3
# 취급액 :  55513000 개수 :  3
# 취급액 :  106981000 개수 :  3
# 취급액 :  87107000 개수 :  3
# 취급액 :  33088000 개수 :  3
# 취급액 :  69037000 개수 :  3
# 취급액 :  57465000 개수 :  2
# 취급액 :  66514000 개수 :  2
# 취급액 :  57036000 개수 :  3
# 취급액 :  94868000 개수 :  3
# 취급액 :  54806000 개수 :  3
# 취급액 :  28165000 개수 :  3
# 취급액 :  22347000 개수 :  3
# 취급액 :  134211000 개수 :  3
# 취급액 :  84252000 개수 :  3
# 취급액 :  60587000 개수 :  3
# 취급액 :  100997000 개수 :  3
# 취급액 :  40258000 개수 :  3
# 취급액 :  11401000 개수 :  3
# 취급액 :  10148000 개수 :  3
# 취급액 :  31672000 개수 :  3
# 취급액 :  123095000 개수 :  3
# 취급액 :  143390000 개수 :  3
# 취급액 :  87820000 개수 :  2
# 취급액 :  68253000 개수 :  2
# 취급액 :  2405000 개수 :  2
# 취급액 :  4936000 개수 :  2
# 취급액 :  16413000 개수 :  2
# 취급액 :  3280000 개수 :  2
# 취급액 :  3533000 개수 :  2
# 취급액 :  30216000 개수 :  2
# 취급액 :  105009000 개수 :  3
# 취급액 :  111613000 개수 :  3
# 취급액 :  109399000 개수 :  3
# 취급액 :  30549000 개수 :  2
# 취급액 :  35885000 개수 :  2
# 취급액 :  157104000 개수 :  3
# 취급액 :  54302000 개수 :  3
# 취급액 :  158508000 개수 :  3
# 취급액 :  85092000 개수 :  3
# 취급액 :  41822000 개수 :  3
# 취급액 :  7527000 개수 :  3
# 취급액 :  74871000 개수 :  3
# 취급액 :  51002000 개수 :  3
# 취급액 :  147747000 개수 :  3
# 취급액 :  36970000 개수 :  3
# 취급액 :  107385000 개수 :  3
# 취급액 :  74957000 개수 :  3
# 취급액 :  29936000 개수 :  3
# 취급액 :  48665000 개수 :  3
# 취급액 :  48875000 개수 :  3
# 취급액 :  9891000 개수 :  3
# 취급액 :  19434000 개수 :  3
# 취급액 :  43678000 개수 :  3
# 취급액 :  120367000 개수 :  3
# 취급액 :  150873000 개수 :  3
# 취급액 :  121425000 개수 :  3
# 취급액 :  41467000 개수 :  3
# 취급액 :  50612000 개수 :  3
# 취급액 :  53118000 개수 :  3
# 취급액 :  63380000 개수 :  3
# 취급액 :  84770000 개수 :  3
# 취급액 :  86202000 개수 :  3
# 취급액 :  56790000 개수 :  2
# 취급액 :  76477000 개수 :  3
# 취급액 :  120425000 개수 :  3
# 취급액 :  168869000 개수 :  3
# 취급액 :  1586000 개수 :  3
# 취급액 :  202223000 개수 :  3
# 취급액 :  60637000 개수 :  3
# 취급액 :  14213000 개수 :  3
# 취급액 :  110750000 개수 :  3
# 취급액 :  40999000 개수 :  3
# 취급액 :  100468000 개수 :  3
# 취급액 :  40108000 개수 :  3
# 취급액 :  14927000 개수 :  3
# 취급액 :  113666000 개수 :  3
# 취급액 :  31462000 개수 :  3
# 취급액 :  94059000 개수 :  3
# 취급액 :  181925000 개수 :  3
# 취급액 :  143530000 개수 :  3
# 취급액 :  87878000 개수 :  2
# 취급액 :  106503000 개수 :  3
# 취급액 :  45617000 개수 :  3
# 취급액 :  33283000 개수 :  3
# 취급액 :  81992000 개수 :  3
# 취급액 :  7810000 개수 :  3
# 취급액 :  77911000 개수 :  3
# 취급액 :  23361000 개수 :  3
# 취급액 :  121602000 개수 :  3
# 취급액 :  13979000 개수 :  3
# 취급액 :  102399000 개수 :  3
# 취급액 :  77890000 개수 :  3
# 취급액 :  40152000 개수 :  3
# 취급액 :  41881000 개수 :  3
# 취급액 :  48668000 개수 :  3
# 취급액 :  33362000 개수 :  3
# 취급액 :  136934000 개수 :  3
# 취급액 :  130991000 개수 :  3
# 취급액 :  42514000 개수 :  2
# 취급액 :  47533000 개수 :  2
# 취급액 :  55391000 개수 :  3
# 취급액 :  132646000 개수 :  3
# 취급액 :  4719000 개수 :  3
# 취급액 :  14794000 개수 :  3
# 취급액 :  7015000 개수 :  3
# 취급액 :  8069000 개수 :  3
# 취급액 :  30342000 개수 :  3
# 취급액 :  27910000 개수 :  3
# 취급액 :  8281000 개수 :  3
# 취급액 :  103623000 개수 :  3
# 취급액 :  25344000 개수 :  3
# 취급액 :  81144000 개수 :  3
# 취급액 :  92062000 개수 :  3
# 취급액 :  90692000 개수 :  3
# 취급액 :  63055000 개수 :  3
# 취급액 :  41822000 개수 :  3
# 취급액 :  12909000 개수 :  3
# 취급액 :  11588000 개수 :  3
# 취급액 :  27142000 개수 :  3
# 취급액 :  183094000 개수 :  3
# 취급액 :  110400000 개수 :  3
# 취급액 :  107751000 개수 :  3
# 취급액 :  164190000 개수 :  3
# 취급액 :  57432000 개수 :  3
# 취급액 :  106986000 개수 :  3
# 취급액 :  106441000 개수 :  3
# 취급액 :  52408000 개수 :  3
# 취급액 :  27802000 개수 :  3
# 취급액 :  78015000 개수 :  3
# 취급액 :  8451000 개수 :  3
# 취급액 :  13947000 개수 :  3
# 취급액 :  32451000 개수 :  3
# 취급액 :  21609000 개수 :  3
# 취급액 :  26822000 개수 :  3
# ...
# 취급액 :  143265000 개수 :  3
# 취급액 :  73780000 개수 :  3
# 취급액 :  174621000 개수 :  3
# 취급액 :  115659000 개수 :  3
# 취급액 :  71545000 개수 :  3
# 취급액 :  136712000 개수 :  3
# 취급액 :  105806000 개수 :  3
# 취급액 :  234831000 개수 :  3
# 취급액 :  132625000 개수 :  3
# 취급액 :  145180000 개수 :  3
# 취급액 :  59323000 개수 :  3
# 취급액 :  30972000 개수 :  3
# 취급액 :  66264000 개수 :  3
# 취급액 :  124099000 개수 :  3
# 취급액 :  35094000 개수 :  3
# 취급액 :  14417000 개수 :  3
# 취급액 :  40865000 개수 :  3
# 취급액 :  22026000 개수 :  3
# 취급액 :  76427000 개수 :  3
# 취급액 :  16380000 개수 :  3
# 취급액 :  60879000 개수 :  3
# 취급액 :  87130000 개수 :  3
# 취급액 :  75363000 개수 :  3
# 취급액 :  133444000 개수 :  3
# 취급액 :  54516000 개수 :  3
# 취급액 :  105122000 개수 :  3
# 취급액 :  45021000 개수 :  3
# 취급액 :  157908000 개수 :  3
# 취급액 :  48282000 개수 :  3
# 취급액 :  144445000 개수 :  3
# 취급액 :  211025000 개수 :  3
# 취급액 :  26072000 개수 :  2
# 취급액 :  33265000 개수 :  2
# 취급액 :  14443000 개수 :  2
# 취급액 :  7649000 개수 :  2
# 취급액 :  19309000 개수 :  2
# 취급액 :  5551000 개수 :  2
# 취급액 :  164616000 개수 :  3
# 취급액 :  119913000 개수 :  3
# 취급액 :  152046000 개수 :  3
# 취급액 :  212374000 개수 :  3
# 취급액 :  159617000 개수 :  3
# 취급액 :  22852000 개수 :  3
# 취급액 :  9190000 개수 :  3
# 취급액 :  43538000 개수 :  3
# 취급액 :  40228000 개수 :  3
# 취급액 :  14443000 개수 :  3
# 취급액 :  7392000 개수 :  3
# 취급액 :  93699000 개수 :  3
# 취급액 :  107428000 개수 :  3
# 취급액 :  75972000 개수 :  3
# 취급액 :  77796000 개수 :  3
# 취급액 :  188654000 개수 :  3
# 취급액 :  143221000 개수 :  3
# 취급액 :  94445000 개수 :  3
# 취급액 :  37063000 개수 :  3
# 취급액 :  33637000 개수 :  3
# 취급액 :  9104000 개수 :  3
# 취급액 :  108527000 개수 :  3
# 취급액 :  25601000 개수 :  2
# 취급액 :  21355000 개수 :  2
# 취급액 :  27822000 개수 :  2
# 취급액 :  77743000 개수 :  2
# 취급액 :  29184000 개수 :  2
# 취급액 :  15462000 개수 :  2
# 취급액 :  6191000 개수 :  2
# 취급액 :  180271000 개수 :  6
# ------------------------------------------------ (12, 14, 200125)
# 취급액 :  157665000 개수 :  3
# 취급액 :  38025000 개수 :  3
# 취급액 :  23510000 개수 :  3
# 취급액 :  60381000 개수 :  3
# 취급액 :  94716000 개수 :  3
# 취급액 :  20390000 개수 :  2
# 취급액 :  16061000 개수 :  2
# 취급액 :  147824000 개수 :  3
# 취급액 :  60577000 개수 :  3
# 취급액 :  27967000 개수 :  3
# 취급액 :  38900000 개수 :  3
# 취급액 :  17484000 개수 :  3
# 취급액 :  47768000 개수 :  3
# 취급액 :  64546000 개수 :  3
# 취급액 :  20696000 개수 :  3
# 취급액 :  17633000 개수 :  3
# 취급액 :  103313000 개수 :  3
# 취급액 :  49702000 개수 :  3
# 취급액 :  213143000 개수 :  3
# 취급액 :  280205000 개수 :  4
# 취급액 :  106864000 개수 :  3
# 취급액 :  66158000 개수 :  3
# 취급액 :  82939000 개수 :  3
# 취급액 :  19706000 개수 :  3
# 취급액 :  29922000 개수 :  3
# 취급액 :  73595000 개수 :  3
# 취급액 :  51303000 개수 :  1
# 취급액 :  183249000 개수 :  6
# ------------------------------------------------ (12, 15, 200153)
# 취급액 :  218562000 개수 :  3
# 취급액 :  36342000 개수 :  3
# 취급액 :  81692000 개수 :  3
# 취급액 :  230882000 개수 :  3
# 취급액 :  178010000 개수 :  3
# 취급액 :  16732000 개수 :  2
# 취급액 :  8838000 개수 :  2
# 취급액 :  197904000 개수 :  3
# 취급액 :  47561000 개수 :  6
# ------------------------------------------------ (12, 15, 201169)
# 취급액 :  25643000 개수 :  6
# ------------------------------------------------ (12, 15, 201172)
# 취급액 :  77289000 개수 :  6
# ------------------------------------------------ (12, 15, 201180)
# 취급액 :  67489000 개수 :  6
# ------------------------------------------------ (12, 15, 201182)
# 취급액 :  35004000 개수 :  6
# ------------------------------------------------ (12, 15, 201184)
# 취급액 :  20076000 개수 :  6
# ------------------------------------------------ (12, 15, 201187)
# 취급액 :  25090000 개수 :  3
# 취급액 :  22039000 개수 :  3
# 취급액 :  25443000 개수 :  3
# 취급액 :  16235000 개수 :  3
# 취급액 :  38177000 개수 :  3
# 취급액 :  39227000 개수 :  3
# 취급액 :  25580000 개수 :  3
# 취급액 :  33756000 개수 :  3
# 취급액 :  36270000 개수 :  3
# 취급액 :  24673000 개수 :  3
# 취급액 :  124017000 개수 :  3
# 취급액 :  210301000 개수 :  3
# 취급액 :  66448000 개수 :  3
# 취급액 :  104655000 개수 :  3
# 취급액 :  212460000 개수 :  3
# 취급액 :  102362000 개수 :  3
# 취급액 :  122924000 개수 :  3
# 취급액 :  22045000 개수 :  3
# 취급액 :  29152000 개수 :  3
# 취급액 :  107275000 개수 :  3
# 취급액 :  141105000 개수 :  4
# 취급액 :  41102000 개수 :  3
# 취급액 :  21987000 개수 :  3
# 취급액 :  10924000 개수 :  3
# 취급액 :  81536000 개수 :  3
# 취급액 :  100562000 개수 :  3
# 취급액 :  94662000 개수 :  3
# 취급액 :  1683000 개수 :  3
# 취급액 :  40890000 개수 :  3
# 취급액 :  11203000 개수 :  3
# 취급액 :  115386000 개수 :  3
# 취급액 :  123679000 개수 :  3
# 취급액 :  23223000 개수 :  3
# 취급액 :  24499000 개수 :  3
# 취급액 :  32150000 개수 :  3
# 취급액 :  92234000 개수 :  3
# 취급액 :  130552000 개수 :  3
# 취급액 :  76557000 개수 :  3
# 취급액 :  276321000 개수 :  3
# 취급액 :  50369000 개수 :  3
# 취급액 :  50360000 개수 :  3
# 취급액 :  10304000 개수 :  3
# 취급액 :  43875000 개수 :  3
# 취급액 :  33040000 개수 :  3
# 취급액 :  101951000 개수 :  3
# 취급액 :  194812000 개수 :  3
# 취급액 :  108338000 개수 :  3
# 취급액 :  47359000 개수 :  3
# 취급액 :  37869000 개수 :  3
# 취급액 :  55864000 개수 :  3
# 취급액 :  10317000 개수 :  3
# 취급액 :  12770000 개수 :  3
# 취급액 :  51010000 개수 :  3
# 취급액 :  32218000 개수 :  2
# 취급액 :  23651000 개수 :  2
# 취급액 :  30211000 개수 :  2
# 취급액 :  62658000 개수 :  2
# 취급액 :  22354000 개수 :  2
# 취급액 :  35537000 개수 :  2
# 취급액 :  4664000 개수 :  2
# 취급액 :  42345000 개수 :  3
# 취급액 :  188295000 개수 :  3
# 취급액 :  63621000 개수 :  3
# 취급액 :  180859000 개수 :  3
# 취급액 :  112014000 개수 :  3
# 취급액 :  118543000 개수 :  3
# 취급액 :  35948000 개수 :  3
# 취급액 :  87239000 개수 :  3
# 취급액 :  28029000 개수 :  3
# 취급액 :  17201000 개수 :  3
# 취급액 :  45261000 개수 :  3
# 취급액 :  46564000 개수 :  3
# 취급액 :  20761000 개수 :  3
# 취급액 :  15807000 개수 :  3
# 취급액 :  83243000 개수 :  3
# 취급액 :  33211000 개수 :  3
# 취급액 :  166313000 개수 :  3
# 취급액 :  58966000 개수 :  3
# 취급액 :  17333000 개수 :  3
# 취급액 :  91815000 개수 :  3
# 취급액 :  48627000 개수 :  3
# 취급액 :  66970000 개수 :  3
# 취급액 :  100192000 개수 :  3
# 취급액 :  183830000 개수 :  3
# 취급액 :  78772000 개수 :  3
# 취급액 :  175061000 개수 :  3
# 취급액 :  29266000 개수 :  3
# 취급액 :  62180000 개수 :  3
# 취급액 :  46151000 개수 :  3
# 취급액 :  176344000 개수 :  6
# ------------------------------------------------ (12, 18, 200153)
# 취급액 :  178542000 개수 :  3
# 취급액 :  99736000 개수 :  4
# 취급액 :  149666000 개수 :  3
# 취급액 :  28891000 개수 :  3
# 취급액 :  19351000 개수 :  3
# 취급액 :  280152000 개수 :  3
# 취급액 :  138933000 개수 :  3
# 취급액 :  14594000 개수 :  3
# 취급액 :  8133000 개수 :  3
# 취급액 :  28760000 개수 :  3
# 취급액 :  13129000 개수 :  3
# 취급액 :  28402000 개수 :  3
# 취급액 :  38873000 개수 :  3
# 취급액 :  15762000 개수 :  3
# 취급액 :  26342000 개수 :  3
# 취급액 :  795000 개수 :  3
# 취급액 :  88822000 개수 :  3
# 취급액 :  56424000 개수 :  3
# 취급액 :  77669000 개수 :  3
# 취급액 :  129072000 개수 :  3
# 취급액 :  24950000 개수 :  3
# 취급액 :  6723000 개수 :  3
# 취급액 :  121034000 개수 :  3
# 취급액 :  102256000 개수 :  3
# 취급액 :  173900000 개수 :  3
# 취급액 :  104103000 개수 :  3
# 취급액 :  29083000 개수 :  3
# 취급액 :  29122000 개수 :  3
# 취급액 :  70436000 개수 :  3
# 취급액 :  95700000 개수 :  3
# 취급액 :  386501000 개수 :  4
# 취급액 :  33070000 개수 :  3
# 취급액 :  120238000 개수 :  3
# 취급액 :  41530000 개수 :  3
# 취급액 :  104623000 개수 :  3
# 취급액 :  134729000 개수 :  3
# 취급액 :  121722000 개수 :  3
# 취급액 :  154647000 개수 :  3
# 취급액 :  57998000 개수 :  3
# 취급액 :  38127000 개수 :  3
# 취급액 :  75189000 개수 :  3
# 취급액 :  196642000 개수 :  3
# 취급액 :  79400000 개수 :  2
# 취급액 :  17610000 개수 :  3
# 취급액 :  10950000 개수 :  3
# 취급액 :  37696000 개수 :  3
# 취급액 :  42009000 개수 :  3
# 취급액 :  11149000 개수 :  3
# 취급액 :  10293000 개수 :  3
# 취급액 :  92715000 개수 :  3
# 취급액 :  136695000 개수 :  3
# 취급액 :  52977000 개수 :  3
# 취급액 :  145277000 개수 :  12
# 취급액 :  526985000 개수 :  12
# 취급액 :  213063000 개수 :  3
# 취급액 :  143426000 개수 :  3
# 취급액 :  185575000 개수 :  3
# 취급액 :  241240000 개수 :  3
# 취급액 :  15266000 개수 :  3
# 취급액 :  17829000 개수 :  3
# 취급액 :  68522000 개수 :  3
# 취급액 :  19101000 개수 :  3
# 취급액 :  31874000 개수 :  3
# 취급액 :  124933000 개수 :  3
# 취급액 :  173258000 개수 :  3
# 취급액 :  70847000 개수 :  3
# 취급액 :  134973000 개수 :  3
# 취급액 :  18060000 개수 :  3
# 취급액 :  13836000 개수 :  3
# 취급액 :  50924000 개수 :  3
# 취급액 :  19308000 개수 :  3
# 취급액 :  30960000 개수 :  3
# 취급액 :  67416000 개수 :  3
# 취급액 :  73399000 개수 :  2
# 취급액 :  176105000 개수 :  3
# 취급액 :  294899000 개수 :  3
# 취급액 :  34699000 개수 :  3
# 취급액 :  36172000 개수 :  3
# 취급액 :  3042000 개수 :  3
# 취급액 :  54157000 개수 :  3
# 취급액 :  118748000 개수 :  3
# 취급액 :  105884000 개수 :  3
# 취급액 :  124293000 개수 :  3
# 취급액 :  135122000 개수 :  3
# 취급액 :  56239000 개수 :  1
# 취급액 :  36676000 개수 :  2
# 취급액 :  31695000 개수 :  2
# 취급액 :  35399000 개수 :  2
# 취급액 :  78216000 개수 :  2
# 취급액 :  22354000 개수 :  2
# 취급액 :  33382000 개수 :  2
# 취급액 :  9074000 개수 :  2
# 취급액 :  163528000 개수 :  3
# 취급액 :  186509000 개수 :  3
# 취급액 :  163602000 개수 :  3
# 취급액 :  110554000 개수 :  2
# 취급액 :  330609000 개수 :  3
# 취급액 :  174358000 개수 :  3
# 취급액 :  256383000 개수 :  2
# 취급액 :  80940000 개수 :  3
# 취급액 :  47793000 개수 :  3
# 취급액 :  169903000 개수 :  3
# 취급액 :  204318000 개수 :  3
# 취급액 :  185520000 개수 :  3
# 취급액 :  81321000 개수 :  3
# 취급액 :  60394000 개수 :  3
# 취급액 :  138076000 개수 :  3
# 취급액 :  69732000 개수 :  3
# 취급액 :  22049000 개수 :  3
# 취급액 :  26908000 개수 :  3
# 취급액 :  64723000 개수 :  3
# 취급액 :  209731000 개수 :  6
# ------------------------------------------------ (12, 22, 200125)
# 취급액 :  185646000 개수 :  6
# ------------------------------------------------ (12, 22, 200153)
# 취급액 :  51227000 개수 :  3
# 취급액 :  77162000 개수 :  2
# 취급액 :  363977000 개수 :  4
# 취급액 :  207156000 개수 :  3
# 취급액 :  296332000 개수 :  6
# ------------------------------------------------ (12, 22, 201322)
# 취급액 :  86426000 개수 :  3
# 취급액 :  42721000 개수 :  3
# 취급액 :  31844000 개수 :  3
# 취급액 :  14341000 개수 :  3
# 취급액 :  55378000 개수 :  3
# 취급액 :  33805000 개수 :  3
# 취급액 :  50753000 개수 :  3
# 취급액 :  92307000 개수 :  3
# 취급액 :  145011000 개수 :  3
# 취급액 :  150326000 개수 :  3
# 취급액 :  19665000 개수 :  2
# 취급액 :  139417000 개수 :  3
# 취급액 :  24803000 개수 :  3
# 취급액 :  7413000 개수 :  3
# 취급액 :  118131000 개수 :  3
# 취급액 :  84592000 개수 :  3
# 취급액 :  145881000 개수 :  3
# 취급액 :  133712000 개수 :  6
# ------------------------------------------------ (12, 23, 200153)
# 취급액 :  56868000 개수 :  3
# 취급액 :  115982000 개수 :  3
# 취급액 :  77148000 개수 :  3
# 취급액 :  195639000 개수 :  3
# 취급액 :  13578000 개수 :  3
# 취급액 :  13765000 개수 :  3
# 취급액 :  47621000 개수 :  3
# 취급액 :  9850000 개수 :  3
# 취급액 :  22082000 개수 :  3
# 취급액 :  123534000 개수 :  3
# 취급액 :  141086000 개수 :  3
# 취급액 :  119175000 개수 :  3
# 취급액 :  112058000 개수 :  3
# 취급액 :  10935000 개수 :  3
# 취급액 :  5624000 개수 :  3
# 취급액 :  34755000 개수 :  3
# 취급액 :  13071000 개수 :  3
# 취급액 :  31123000 개수 :  3
# 취급액 :  81036000 개수 :  3
# 취급액 :  69074000 개수 :  3
# 취급액 :  33390000 개수 :  3
# 취급액 :  17696000 개수 :  3
# 취급액 :  68750000 개수 :  3
# 취급액 :  22116000 개수 :  2
# 취급액 :  67112000 개수 :  2
# 취급액 :  28521000 개수 :  2
# 취급액 :  19341000 개수 :  2
# 취급액 :  130201000 개수 :  3
# 취급액 :  24079000 개수 :  3
# 취급액 :  6678000 개수 :  3
# 취급액 :  169333000 개수 :  3
# 취급액 :  97615000 개수 :  3
# 취급액 :  58874000 개수 :  3
# 취급액 :  57410000 개수 :  3
# 취급액 :  73884000 개수 :  2
# 취급액 :  57141000 개수 :  2
# 취급액 :  50259000 개수 :  2
# 취급액 :  54051000 개수 :  2
# 취급액 :  73769000 개수 :  2
# 취급액 :  35763000 개수 :  2
# 취급액 :  13795000 개수 :  2
# 취급액 :  158529000 개수 :  3
# 취급액 :  58201000 개수 :  3
# 취급액 :  179858000 개수 :  2
# 취급액 :  206956000 개수 :  3
# 취급액 :  60668000 개수 :  1
# 취급액 :  106137000 개수 :  3
# 취급액 :  91791000 개수 :  3
# 취급액 :  113327000 개수 :  3
# 취급액 :  42757000 개수 :  3
# 취급액 :  19623000 개수 :  3
# 취급액 :  55976000 개수 :  3
# 취급액 :  25781000 개수 :  3
# 취급액 :  38115000 개수 :  3
# 취급액 :  57451000 개수 :  3
# 취급액 :  8455000 개수 :  3
# 취급액 :  38625000 개수 :  3
# 취급액 :  12199000 개수 :  3
# 취급액 :  96907000 개수 :  3
# 취급액 :  177374000 개수 :  3
# 취급액 :  79580000 개수 :  6
# ------------------------------------------------ (12, 24, 201635)
# 취급액 :  124076000 개수 :  3
# 취급액 :  23438000 개수 :  3
# 취급액 :  61901000 개수 :  3
# 취급액 :  18583000 개수 :  2
# 취급액 :  7285000 개수 :  2
# 취급액 :  52438000 개수 :  2
# 취급액 :  112210000 개수 :  6
# ------------------------------------------------ (12, 24, 202210)
# 취급액 :  168590000 개수 :  3
# 취급액 :  167076000 개수 :  3
# 취급액 :  34788000 개수 :  2
# 취급액 :  21599000 개수 :  2
# 취급액 :  23604000 개수 :  2
# 취급액 :  14956000 개수 :  2
# 취급액 :  29777000 개수 :  2
# 취급액 :  10340000 개수 :  2
# 취급액 :  6187000 개수 :  2
# 취급액 :  269998000 개수 :  3
# 취급액 :  200159000 개수 :  3
# 취급액 :  165147000 개수 :  3
# 취급액 :  206367000 개수 :  3
# 취급액 :  114258000 개수 :  3
# 취급액 :  64339000 개수 :  3
# 취급액 :  74706000 개수 :  3
# 취급액 :  142163000 개수 :  3
# 취급액 :  57549000 개수 :  2
# 취급액 :  31154000 개수 :  2
# 취급액 :  12286000 개수 :  2
# 취급액 :  43340000 개수 :  2
# 취급액 :  150712000 개수 :  3
# 취급액 :  27513000 개수 :  3
# 취급액 :  9523000 개수 :  3
# 취급액 :  47108000 개수 :  3
# 취급액 :  283582000 개수 :  3
# 취급액 :  245818000 개수 :  3
# 취급액 :  87723000 개수 :  3
# 취급액 :  18921000 개수 :  3
# 취급액 :  27658000 개수 :  3
# 취급액 :  77498000 개수 :  3
# 취급액 :  107528000 개수 :  3
# 취급액 :  31971000 개수 :  3
# 취급액 :  34817000 개수 :  3
# 취급액 :  71499000 개수 :  6
# ------------------------------------------------ (12, 26, 200008)
# 취급액 :  46502000 개수 :  6
# ------------------------------------------------ (12, 26, 200009)
# 취급액 :  94554000 개수 :  3
# 취급액 :  120592000 개수 :  3
# 취급액 :  155254000 개수 :  3
# 취급액 :  147565000 개수 :  3
# 취급액 :  78194000 개수 :  3
# 취급액 :  10124000 개수 :  6
# ------------------------------------------------ (12, 26, 201000)
# 취급액 :  84874000 개수 :  6
# ------------------------------------------------ (12, 26, 201001)
# 취급액 :  33056000 개수 :  3
# 취급액 :  364133000 개수 :  3
# 취급액 :  157839000 개수 :  3
# 취급액 :  100604000 개수 :  3
# 취급액 :  35950000 개수 :  3
# 취급액 :  20840000 개수 :  3
# 취급액 :  61967000 개수 :  3
# 취급액 :  70880000 개수 :  3
# 취급액 :  24281000 개수 :  3
# 취급액 :  19837000 개수 :  3
# 취급액 :  117239000 개수 :  3
# 취급액 :  151091000 개수 :  3
# 취급액 :  70128000 개수 :  3
# 취급액 :  159058000 개수 :  3
# 취급액 :  181720000 개수 :  3
# 취급액 :  81213000 개수 :  3
# 취급액 :  194684000 개수 :  3
# 취급액 :  101691000 개수 :  3
# 취급액 :  6210000 개수 :  3
# 취급액 :  3025000 개수 :  3
# 취급액 :  63701000 개수 :  3
# 취급액 :  43585000 개수 :  3
# 취급액 :  36787000 개수 :  3
# 취급액 :  70743000 개수 :  3
# 취급액 :  137008000 개수 :  3
# 취급액 :  115355000 개수 :  3
# 취급액 :  106500000 개수 :  3
# 취급액 :  194015000 개수 :  3
# 취급액 :  46658000 개수 :  3
# 취급액 :  45347000 개수 :  3
# 취급액 :  71247000 개수 :  3
# 취급액 :  136874000 개수 :  3
# 취급액 :  95441000 개수 :  3
# 취급액 :  107892000 개수 :  3
# 취급액 :  17599000 개수 :  3
# 취급액 :  7390000 개수 :  3
# 취급액 :  145265000 개수 :  3
# 취급액 :  158802000 개수 :  3
# 취급액 :  75174000 개수 :  6
# ------------------------------------------------ (12, 27, 202210)
# 취급액 :  85808000 개수 :  3
# 취급액 :  33664000 개수 :  2
# 취급액 :  15818000 개수 :  2
# 취급액 :  20660000 개수 :  2
# 취급액 :  31388000 개수 :  2
# 취급액 :  29777000 개수 :  2
# 취급액 :  30514000 개수 :  2
# 취급액 :  7511000 개수 :  2
# 취급액 :  220713000 개수 :  6
# ------------------------------------------------ (12, 28, 200153)
# 취급액 :  144627000 개수 :  3
# 취급액 :  172725000 개수 :  3
# 취급액 :  110684000 개수 :  2
# 취급액 :  169942000 개수 :  3
# 취급액 :  155750000 개수 :  3
# 취급액 :  261372000 개수 :  3
# 취급액 :  262811000 개수 :  3
# 취급액 :  159272000 개수 :  3
# 취급액 :  20732000 개수 :  3
# 취급액 :  14318000 개수 :  3
# 취급액 :  52603000 개수 :  3
# 취급액 :  33586000 개수 :  3
# 취급액 :  15497000 개수 :  3
# 취급액 :  8577000 개수 :  3
# 취급액 :  109429000 개수 :  3
# 취급액 :  105266000 개수 :  3
# 취급액 :  33920000 개수 :  3
# 취급액 :  26354000 개수 :  3
# 취급액 :  61320000 개수 :  3
# 취급액 :  21876000 개수 :  3
# 취급액 :  86449000 개수 :  3
# 취급액 :  41749000 개수 :  3
# 취급액 :  162396000 개수 :  3
# 취급액 :  73672000 개수 :  3
# 취급액 :  155985000 개수 :  3
# 취급액 :  64917000 개수 :  3
# 취급액 :  259765000 개수 :  3
# 취급액 :  4749000 개수 :  3
# 취급액 :  47451000 개수 :  3
# 취급액 :  4286000 개수 :  3
# 취급액 :  195286000 개수 :  3
# 취급액 :  151504000 개수 :  3
# 취급액 :  153025000 개수 :  3
# 취급액 :  153446000 개수 :  3
# 취급액 :  131115000 개수 :  3
# 취급액 :  29071000 개수 :  2
# 취급액 :  207803000 개수 :  3
# 취급액 :  63086000 개수 :  3
# 취급액 :  55583000 개수 :  3
# 취급액 :  191231000 개수 :  3
# 취급액 :  34556000 개수 :  3
# 취급액 :  13131000 개수 :  3
# 취급액 :  75874000 개수 :  3
# 취급액 :  246562000 개수 :  3
# 취급액 :  247609000 개수 :  3
# 취급액 :  137319000 개수 :  3
# 취급액 :  94301000 개수 :  3
# 취급액 :  18122000 개수 :  3
# 취급액 :  20943000 개수 :  3
# 취급액 :  78957000 개수 :  3
# 취급액 :  124013000 개수 :  6
# ------------------------------------------------ (12, 30, 200153)
# 취급액 :  209878000 개수 :  3
# 취급액 :  237065000 개수 :  3
# 취급액 :  118920000 개수 :  3
# 취급액 :  102819000 개수 :  3
# 취급액 :  105504000 개수 :  3
# 취급액 :  54135000 개수 :  3
# 취급액 :  168428000 개수 :  3
# 취급액 :  174112000 개수 :  3
# 취급액 :  87295000 개수 :  3
# 취급액 :  59161000 개수 :  3
# 취급액 :  23041000 개수 :  3
# 취급액 :  80326000 개수 :  3
# 취급액 :  58445000 개수 :  3
# 취급액 :  111865000 개수 :  3
# 취급액 :  60681000 개수 :  3
# 취급액 :  107529000 개수 :  3
# 취급액 :  11792000 개수 :  3
# 취급액 :  7772000 개수 :  3
# 취급액 :  132711000 개수 :  3
# 취급액 :  84447000 개수 :  3
# 취급액 :  96356000 개수 :  6
# ------------------------------------------------ (12, 30, 202210)
# 취급액 :  80798000 개수 :  3
# 취급액 :  76448000 개수 :  3
# 취급액 :  145574000 개수 :  3
# 취급액 :  24205000 개수 :  3
# 취급액 :  152722000 개수 :  3
# 취급액 :  72863000 개수 :  3
# 취급액 :  152853000 개수 :  3
# 취급액 :  179279000 개수 :  3
# 취급액 :  201322000 개수 :  3
# 취급액 :  76376000 개수 :  3
# 취급액 :  148787000 개수 :  3
# 취급액 :  41199000 개수 :  3
# 취급액 :  41418000 개수 :  3
# 취급액 :  64651000 개수 :  3
# 취급액 :  16713000 개수 :  3
# 취급액 :  128803000 개수 :  3
# 취급액 :  58429000 개수 :  3
# 취급액 :  81828000 개수 :  3
# 취급액 :  17216000 개수 :  3
# 취급액 :  39948000 개수 :  3
# 취급액 :  26317000 개수 :  3
# 취급액 :  108229000 개수 :  3
# 취급액 :  26301000 개수 :  3
# 취급액 :  27069000 개수 :  3
# 취급액 :  48990000 개수 :  3
# 취급액 :  140548000 개수 :  3
# 취급액 :  73048000 개수 :  3
# 취급액 :  11882000 개수 :  3
# 취급액 :  21743000 개수 :  3
# 취급액 :  49330000 개수 :  3

# %% [markdown]
# ## 새로운col만들기
# * new_idx (month, day, 상품코드) / 취급액
# * new_idx, 취급액, 연속노출편성횟수(20 * 3), 한번에몇개판매(한 편성안에 몇개의 제품 판매)
# * new_idx, 취급액, 연속노출편성횟수, 한번에몇개판매, idx가 같은 애들(연속 노출편성) 취급액 합, 취급액 / 연속노출편성 취급액 합

# %%
# 새로운 col 생성
df['new_idx'] = df['month'].astype(str)+df['day'].astype(str)+df['상품코드'].astype(str)
new = df.loc[:,['new_idx',' 취급액 ']]

idxs, times,items = [], [], []
tmp_times, tmp_items = [], []


time = 1
item = 0
i = 0

while i < 37364:

    if new['new_idx'][i] not in idxs :
        idxs.append(new['new_idx'][i])
        item += 1
        i += 1
        time = 1
    
    else : 
        time += 1
        ## time 세는 거
        if new['new_idx'][i+item] == new['new_idx'][i] :
            i += item
        else :
            i += item
            mul = time * item
            
            # column 생성용
            for x in range(mul) :
                times.append( time )
                items.append( item )
            
            # 다음 코딩용
            for x in range(item) :
                tmp_times.append(time)
                tmp_items.append(item)
                
            item, time, idxs = 0, 0, []
    
new['items'] = items
new['repeat'] = times

# %%
def check_idx(li, idx_num) :
    li[idx_num] = 1
    return li

def my_turn(li) :
    return li.index(0)

not_yet = [0]*37372
total = [0]*37372

for x, y in zip(tmp_times, tmp_items) :
    tmp_sum = 0
    i = my_turn(not_yet)

    tmp_idx = []
    for k in range(x) : 
        tmp_idx.append(i)
        tmp_sum += new[' 취급액 '][i]
        not_yet = check_idx(not_yet, i)
        i += new['items'][i]
    
    for idx_num in tmp_idx :
        total[idx_num] = tmp_sum    
    
new['total'] = total
new['취급액/total'] = new[' 취급액 ']/new['total']
new['취급액']=new[' 취급액 ']
tmp = pd.concat([df, new], axis=1)
new_data = tmp.loc[: ,['month','day','요일','hour','minute','노출(분)','repeat','상품군','마더코드','상품코드','items','상품명','pay_type','판매단가','취급액/total','취급액']]

# %% [markdown]
# ## 노출시간으로 그래서 뭘볼거지 ?!

# %%
new_data = pd.read_csv('./data/train3.csv', encoding='cp949')
new_data
# Out:
#        month  day  요일  hour  minute  노출(분)  repeat 상품군    마더코드    상품코드  items  \
# 0          1    1   1     6       0     20       3  의류  100346  201072      2
# 1          1    1   1     6       0     20       3  의류  100346  201079      2
# 2          1    1   1     6      20     20       3  의류  100346  201072      2
# 3          1    1   1     6      20     20       3  의류  100346  201079      2
# 4          1    1   1     6      40     20       3  의류  100346  201072      2
# ...      ...  ...  ..   ...     ...    ...     ...  ..     ...     ...    ...
# 37367     12   31   1    23      40     20       4  주방  100448  201391      3
# 37368     12   31   1    24       0     20       4  주방  100448  201383      3
# 37369     12   31   1    24       0     20       4  주방  100448  201390      3
# 37370     12   31   1    24       0     20       4  주방  100448  201384      3
# 37371     12   31   1    24       0     20       4  주방  100448  201391      3
#
#                  상품명  pay_type    판매단가  취급액/total        취급액
# 0      테이트 남성 셀린니트3종         0   39900   0.174437    2099000
# 1      테이트 여성 셀린니트3종         0   39900   0.211538    4371000
# 2      테이트 남성 셀린니트3종         0   39900   0.271088    3262000
# 3      테이트 여성 셀린니트3종         0   39900   0.336592    6955000
# 4      테이트 남성 셀린니트3종         0   39900   0.554475    6672000
# ...              ...       ...     ...        ...        ...
# 37367     쿠첸압력밥솥 6인용         1  148000   0.240687   10157000
# 37368    쿠첸압력밥솥 10인용         2  178000   0.448955   50929000
# 37369    쿠첸압력밥솥 10인용         1  168000   0.924175  104392000
# 37370     쿠첸압력밥솥 6인용         2  158000   0.326185   13765000
# 37371     쿠첸압력밥솥 6인용         1  148000   0.410864   46608000
#
# [37372 rows x 16 columns]

# %%
new_data['repeat'].groupby(new_data['items']).mean().sort_values().plot(kind='bar')
# items가 많은데 연속 편성 횟수가 작다 ? => 노출 시간이 클 거같음(60분)

# %%
new_data['노출(분)'].groupby(new_data['items']).mean().sort_values().plot(kind='bar')
# 위에서 생각한대로 ! 아이템 수가 많을 수록 평균 노출(분) 시간이 길다

# %% [markdown]
# ### 한개의 item만 방송한다면 ?!

# %%
new_data['취급액'].groupby(new_data['items']).mean().sort_values().plot(kind='bar')
# 한번에 방송하는 아이템의 개수가 적을수록 취급액이 높다

# %%
new_data['취급액'].groupby(new_data['items']).sum().sort_values().plot(kind='bar')
# 한개만 방송한게 진짜 월등히 높네 ?......흠

# %%
new_data.loc[new_data['items']==1]['상품군'].value_counts().plot(kind='pie') # 12610

# %%
new_data['상품군'].value_counts().plot(kind='pie')
# 전체 중 주방, 가전 상품군이 많은 것에 비해서 농수축이 1개의 item만 방송하는 경우가 많음 !!!

# %% [markdown]
# ### item 개수가 많은 방송은 ?
# => 가전, 가구가 월등히 높음
#
# * 주의
# item 개수가 10 개인 것에 아주 많은 것들이 포함됨
# 이걸......찍으려다가
# 10개에 쌀이 한갠데 들어가있는걸 발견했고
# 코드를 다시짜야하네 ? ....한.ㅇㄹ마ㅡ;ㅣㄴㄷㄹ즈{

# %%
new_data.loc[new_data['items']==10]['상품군'].value_counts().plot(kind='pie')

# %%
new_data.loc[new_data['items']==9]['상품군'].value_counts().plot(kind='pie')

# %%
new_data.loc[new_data['items']==8]['상품군'].value_counts().plot(kind='pie')

# %% [markdown]
# # 마더코드 활용

# %%
plt.figure(figsize=(100,5))
plt.rc('font', size=10)
new_data['취급액'].groupby(new_data['마더코드']).mean().sort_values(ascending=False).plot(kind='bar')

# %%
plt.figure(figsize=(100,5))
plt.rc('font', size=10)
new_data['취급액'].groupby(new_data['마더코드']).mean().sort_values(ascending=False)#.plot(kind='bar')
# Out:
# 마더코드
# 100699    8.277417e+07
# 100079    7.666735e+07
# 100548    7.279163e+07
# 100264    7.243833e+07
# 100638    7.138033e+07
#               ...
# 100666    3.428833e+06
# 100144    3.143792e+06
# 100576    2.562278e+06
# 100716    1.926667e+06
# 100503    1.059417e+06
# Name: 취급액, Length: 687, dtype: float64
